# %% [markdown]
# # Imports and Installs

# %%
import matplotlib.pyplot as plt

from copy import deepcopy
from tabulate import tabulate

# %% [markdown]
# # Data

# %%
data_p1 = {1: "GTAATGGACGT",
           2: "GCGTTGCGT",
           3: "GCATCACGCAAT",
           4: "GTGCTACGCCG",
           5: "GGGATGCACG"
           }

data_p2 = {1: "GCCCCTA",
           2: "CTAGCCTCA",
           3: "CTACGCTAA",
           4: "CGAGCTTA",
           5: "CGCGACT"
           }
data_p3 = {1: "GCAGCTA",
           2: "TAGCTCA",
           3: "TACGTTA",
           4: "CGAGCTTA"}

# %% [markdown]
# # Needleman-Wunsch Global Alignment

# %%
def get_score(table_score, c1, c2, s_match, s_nomatch):
    if c1 == c2:
        return table_score + s_match
    else:
        return table_score + s_nomatch

# %%
def plot_table(table, s1, s2):

    # Convert data to strings
    cell_text = []
    for row in table:
        cell_text.append([])
        for val in row:
            cell_text[-1].append("%d"%(val["val"]))

    # Get row labels
    row_labels = []
    for c in s1:
        row_labels.append(c)

    # Get column labels
    col_labels = []
    for c in s2:
        col_labels.append(c)

    # Hide graph
    fig, ax = plt.subplots()
    fig.patch.set_visible(False)
    ax.axis("off")
    ax.axis("tight")

    # Display table
    ax.table = plt.table(cellText=cell_text,
                         rowLabels=row_labels,
                         rowLoc="center",
                         colLabels=col_labels,
                         colLoc="center",
                        #  colWidths=[0.5, 0.5],
                         cellLoc="center"
                         )
    # fig.tight_layout()
    plt.show()

# %%
def needleman_wunsch(s1, s2, s_match=2, s_nomatch=-2, display=False):

    # Add -
    s1 = "-" + s1
    s2 = "-" + s2

    # Set up table
    table = []
    for i in range(len(s1)):
        table.append([])
        for j in range(len(s2)):
            table[-1].append({"val": None, "from": None})

    # Initilize table's first row and column
    table[0][0]["val"] = 0
    for i in range(1, len(s1)):
        table[i][0]["val"] = table[i-1][0]["val"] + s_nomatch
        table[i][0]["from"] = [i-1, 0]
    for j in range(1, len(s2)):
        table[0][j]["val"] = table[0][j-1]["val"] + s_nomatch
        table[0][j]["from"] = [0, j-1]

    # Compute table
    for i in range(1, len(s1)):
        for j in range(1, len(s2)):

            # Calculate values from surrounding cells
            sorter = []
            sorter.append({"val": get_score(table[i-1][j]["val"], s1[i], s2[j], s_match, s_nomatch), "from": [i-1, j]})
            sorter.append({"val": get_score(table[i][j-1]["val"], s1[i], s2[j], s_match, s_nomatch), "from": [i, j-1]})
            sorter.append({"val": get_score(table[i-1][j-1]["val"], s1[i], s2[j], s_match, s_nomatch), "from": [i-1, j-1]})

            # Select and keep best score
            sorter = sorted(sorter, key=lambda x: x["val"], reverse=True)
            table[i][j]["val"] = sorter[0]["val"]
            table[i][j]["from"] = []
            for row in sorter:
                if row["val"] == table[i][j]["val"]:
                    table[i][j]["from"].append(row["from"])

    # Display
    if display == 1:
        table_new = []
        for i in range(len(s1)):
            table_new.append(["%s - %d"%(s1[i], i)])
            for j in range(len(s2)):
                table_new[-1].append(table[i][j])
        h = [-1] + ["%s - %d"%(s2[j], j) for j in range(len(s2))]
        print(tabulate(table_new, tablefmt="plain", headers=h))

        # plot_table(table, s1, s2)

    if display == 2:
        table_new = []
        for i in range(len(s1)):
            table_new.append(["%s  %d"%(s1[i], i)])
            for j in range(len(s2)):
                table_new[-1].append(table[i][j]["val"])
        h = [-1] + ["%s  %d"%(s2[j], j) for j in range(len(s2))]
        print(tabulate(table_new, tablefmt="grid", headers=h))

    return table, table[len(s1)-1][len(s2)-1]["val"]

# %% [markdown]
# # ClustalW Alignment

# %%
def get_pairwise_table(sequences, s_match=2, s_nomatch=-2, mirror=False, display=False):

    # Set up table
    table = [["corner"]]
    for k1 in sequences:
        table.append([k1])
        table[0].append(k1)
        for k2 in sequences:
            table[-1].append(None)

    # Get pairwise alignment scores
    for i, k1 in enumerate(sequences):
        for j, k2 in enumerate(sequences):
            if k1 != k2:
                _, score = needleman_wunsch(sequences[k1], sequences[k2], s_match=s_match, s_nomatch=s_nomatch)
                if i < j:
                    table[i+1][j+1] = score
                elif mirror:
                    table[i+1][j+1] = score

    # Display
    if display:
        print(tabulate(table, tablefmt="grid"))

    return table

# %%
def clustalw(sequences, s_match=2, s_nomatch=-2, display=False):
    seqs = deepcopy(sequences)

    # Get the initial table
    table = get_pairwise_table(seqs, s_match=s_match, s_nomatch=s_nomatch)

    # Iterate until the table is empty
    while len(table) > 2 and len(table[0]) > 2:

        # Get min score on table
        min_s = 1000000000000000
        min_i = None
        min_j = None
        for i in range(1, len(table)):
            for j in range(1, len(table[i])):
                if i < j:
                    if table[i][j] < min_s:
                        min_s = table[i][j]
                        min_i = i
                        min_j = j

        # Record the current pair


        # Delete pair from sequences
        del seqs[min_i]
        del seqs[min_j]

        # Get new table
        table = get_pairwise_table(seqs, s_match=s_match, s_nomatch=s_nomatch)
        if display:
            print(tabulate(table, tablefmt="grid"))
            print()

    # Display
    if display:
        print(tabulate(table, tablefmt="grid"))

# clustalw(data_p1, display=True)

# %% [markdown]
# # STAR Alignment

# %%
def get_center_seq(sequences, s_match=2, s_nomatch=-1, display=False):

    # Get table
    table = get_pairwise_table(sequences, s_match=s_match, s_nomatch=s_nomatch, mirror=True)

    # Compute scores
    max_s = -1111111111111
    max_i = None
    for i in range(1, len(table)):
        s = 0
        for j in range(1, len(table[i])):
            if table[i][j] is not None:
                s += table[i][j]
        table[i].append(s)

        # Get max score
        if s > max_s:
            max_s = s
            max_i = i

    # Update table header
    table[0].append("Score")

    # Display
    if display:
        print(tabulate(table, tablefmt="grid"))

    # Get sequence key
    k = table[max_i][0]

    return table, k

# table, k = get_center_seq(data_p3, s_match=1, s_nomatch=-1, display=True)
# k

# %%
def align_to_center(sequences, s_match=2, s_nomatch=-1):

    # Get center sequence
    _, kc = get_center_seq(sequences, s_match=s_match, s_nomatch=s_nomatch)
    cent = sequences[kc]
    print(cent)

    # Align each sequence to center sequence
    for k in sequences:

        # Get table
        table, score = needleman_wunsch(cent, sequences[k], s_match=s_match, s_nomatch=s_nomatch, display=True)

        # Traverse table
        alignment = []
        prev = table[len(table) - 1][len(table[0]) - 1]["from"]
        while True:
            alignment.insert(0, prev[1])
            curr = table[prev[0]][prev[1]]["from"]
            print(prev, curr)

            prev = deepcopy(curr)

            if curr is None:
                break

        # Get text version of alignment

        print(alignment)

        break


# align_to_center(data_p1)

# %% [markdown]
# # Sum-of-Pair Scoring

# %%
# txt = """S1: G---CCCCT-A
# S2: CTAGCC--TCA
# S3: CTA-CGC-TAA
# S4: CGAGC---TTA
# S5: CGCG---ACT-
# """
# txt = txt.split("\n")
# txt = [x.split(": ") for x in txt]

# sp = 0
# for i in range(len(txt[0][1])):
#     s = []
#     for j in range(len(txt)):

# %% [markdown]
# # Problem 1

# %%
for i, k1 in enumerate(data_p1):
    for j, k2 in enumerate(data_p1):
        if i < j and k1 != k2:
            print(k1, "-", k2)
            _, _ = needleman_wunsch(data_p1[k1], data_p1[k2], display=1)
            print()
# Out:
# 1 - 2
# -1      - - 0                          G - 1                           C - 2                                    G - 3                                          T - 4                                          T - 5                                 G - 6                                 C - 7                                         G - 8                                 T - 9
# - - 0   {'val': 0, 'from': None}       {'val': -2, 'from': [0, 0]}     {'val': -4, 'from': [0, 1]}              {'val': -6, 'from': [0, 2]}                    {'val': -8, 'from': [0, 3]}                    {'val': -10, 'from': [0, 4]}          {'val': -12, 'from': [0, 5]}          {'val': -14, 'from': [0, 6]}                  {'val': -16, 'from': [0, 7]}          {'val': -18, 'from': [0, 8]}
# G - 1   {'val': -2, 'from': [0, 0]}    {'val': 2, 'from': [[0, 0]]}    {'val': 0, 'from': [[1, 1]]}             {'val': 2, 'from': [[1, 2]]}                   {'val': 0, 'from': [[1, 3]]}                   {'val': -2, 'from': [[1, 4]]}         {'val': 0, 'from': [[1, 5]]}          {'val': -2, 'from': [[1, 6]]}                 {'val': 0, 'from': [[1, 7]]}          {'val': -2, 'from': [[1, 8]]}
# T - 2   {'val': -4, 'from': [1, 0]}    {'val': 0, 'from': [[1, 1]]}    {'val': 0, 'from': [[1, 1]]}             {'val': 0, 'from': [[1, 3]]}                   {'val': 4, 'from': [[1, 3]]}                   {'val': 6, 'from': [[2, 4]]}          {'val': 4, 'from': [[2, 5]]}          {'val': 2, 'from': [[2, 6]]}                  {'val': 0, 'from': [[2, 7]]}          {'val': 2, 'from': [[2, 8], [1, 8]]}
# A - 3   {'val': -6, 'from': [2, 0]}    {'val': -2, 'from': [[2, 1]]}   {'val': -2, 'from': [[2, 2], [2, 1]]}    {'val': -2, 'from': [[2, 3], [2, 2]]}          {'val': 2, 'from': [[2, 4]]}                   {'val': 4, 'from': [[2, 5]]}          {'val': 4, 'from': [[2, 5]]}          {'val': 2, 'from': [[3, 6], [2, 6]]}          {'val': 0, 'from': [[3, 7], [2, 7]]}  {'val': 0, 'from': [[2, 9]]}
# A - 4   {'val': -8, 'from': [3, 0]}    {'val': -4, 'from': [[3, 1]]}   {'val': -4, 'from': [[3, 2], [3, 1]]}    {'val': -4, 'from': [[3, 3], [3, 2]]}          {'val': 0, 'from': [[3, 4]]}                   {'val': 2, 'from': [[3, 5]]}          {'val': 2, 'from': [[3, 6], [3, 5]]}  {'val': 2, 'from': [[3, 6]]}                  {'val': 0, 'from': [[4, 7], [3, 7]]}  {'val': -2, 'from': [[3, 9], [4, 8], [3, 8]]}
# T - 5   {'val': -10, 'from': [4, 0]}   {'val': -6, 'from': [[4, 1]]}   {'val': -6, 'from': [[4, 2], [4, 1]]}    {'val': -6, 'from': [[4, 3], [4, 2]]}          {'val': 2, 'from': [[4, 4]]}                   {'val': 4, 'from': [[4, 5], [5, 4]]}  {'val': 2, 'from': [[5, 5]]}          {'val': 0, 'from': [[4, 7], [5, 6], [4, 6]]}  {'val': 0, 'from': [[4, 7]]}          {'val': 2, 'from': [[5, 8], [4, 8]]}
# G - 6   {'val': -12, 'from': [5, 0]}   {'val': -4, 'from': [[5, 1]]}   {'val': -6, 'from': [[6, 1]]}            {'val': -4, 'from': [[5, 3], [6, 2], [5, 2]]}  {'val': 0, 'from': [[5, 4]]}                   {'val': 2, 'from': [[5, 5]]}          {'val': 6, 'from': [[5, 5]]}          {'val': 4, 'from': [[6, 6]]}                  {'val': 6, 'from': [[6, 7]]}          {'val': 4, 'from': [[6, 8]]}
# G - 7   {'val': -14, 'from': [6, 0]}   {'val': -2, 'from': [[6, 1]]}   {'val': -4, 'from': [[7, 1]]}            {'val': -2, 'from': [[6, 3], [7, 2]]}          {'val': -2, 'from': [[6, 4]]}                  {'val': 0, 'from': [[6, 5]]}          {'val': 8, 'from': [[6, 6]]}          {'val': 6, 'from': [[7, 6]]}                  {'val': 8, 'from': [[6, 8], [7, 7]]}  {'val': 6, 'from': [[7, 8]]}
# A - 8   {'val': -16, 'from': [7, 0]}   {'val': -4, 'from': [[7, 1]]}   {'val': -4, 'from': [[7, 1]]}            {'val': -4, 'from': [[7, 3]]}                  {'val': -4, 'from': [[7, 4], [7, 3]]}          {'val': -2, 'from': [[7, 5]]}         {'val': 6, 'from': [[7, 6]]}          {'val': 6, 'from': [[7, 6]]}                  {'val': 6, 'from': [[7, 8]]}          {'val': 6, 'from': [[7, 8]]}
# C - 9   {'val': -18, 'from': [8, 0]}   {'val': -6, 'from': [[8, 1]]}   {'val': -2, 'from': [[8, 2], [8, 1]]}    {'val': -4, 'from': [[9, 2]]}                  {'val': -6, 'from': [[8, 4], [9, 3], [8, 3]]}  {'val': -4, 'from': [[8, 5]]}         {'val': 4, 'from': [[8, 6]]}          {'val': 8, 'from': [[8, 7], [8, 6]]}          {'val': 6, 'from': [[9, 7]]}          {'val': 4, 'from': [[8, 9], [9, 8], [8, 8]]}
# G - 10  {'val': -20, 'from': [9, 0]}   {'val': -4, 'from': [[9, 1]]}   {'val': -4, 'from': [[9, 2]]}            {'val': 0, 'from': [[9, 2]]}                   {'val': -2, 'from': [[10, 3]]}                 {'val': -4, 'from': [[10, 4]]}        {'val': 6, 'from': [[9, 6]]}          {'val': 6, 'from': [[9, 7]]}                  {'val': 10, 'from': [[9, 7]]}         {'val': 8, 'from': [[10, 8]]}
# T - 11  {'val': -22, 'from': [10, 0]}  {'val': -6, 'from': [[10, 1]]}  {'val': -6, 'from': [[10, 2], [10, 1]]}  {'val': -2, 'from': [[10, 3]]}                 {'val': 2, 'from': [[10, 3]]}                  {'val': 4, 'from': [[11, 4]]}         {'val': 4, 'from': [[10, 6]]}         {'val': 4, 'from': [[10, 7], [10, 6]]}        {'val': 8, 'from': [[10, 8]]}         {'val': 12, 'from': [[10, 8]]}
#
# 1 - 3
# -1      - - 0                          G - 1                           C - 2                                    A - 3                                    T - 4                                    C - 5                                  A - 6                                    C - 7                                 G - 8                                  C - 9                                   A - 10                                  A - 11                                            T - 12
# - - 0   {'val': 0, 'from': None}       {'val': -2, 'from': [0, 0]}     {'val': -4, 'from': [0, 1]}              {'val': -6, 'from': [0, 2]}              {'val': -8, 'from': [0, 3]}              {'val': -10, 'from': [0, 4]}           {'val': -12, 'from': [0, 5]}             {'val': -14, 'from': [0, 6]}          {'val': -16, 'from': [0, 7]}           {'val': -18, 'from': [0, 8]}            {'val': -20, 'from': [0, 9]}            {'val': -22, 'from': [0, 10]}                     {'val': -24, 'from': [0, 11]}
# G - 1   {'val': -2, 'from': [0, 0]}    {'val': 2, 'from': [[0, 0]]}    {'val': 0, 'from': [[1, 1]]}             {'val': -2, 'from': [[1, 2]]}            {'val': -4, 'from': [[1, 3]]}            {'val': -6, 'from': [[1, 4]]}          {'val': -8, 'from': [[1, 5]]}            {'val': -10, 'from': [[1, 6]]}        {'val': -8, 'from': [[1, 7]]}          {'val': -10, 'from': [[1, 8]]}          {'val': -12, 'from': [[1, 9]]}          {'val': -14, 'from': [[1, 10]]}                   {'val': -16, 'from': [[1, 11]]}
# T - 2   {'val': -4, 'from': [1, 0]}    {'val': 0, 'from': [[1, 1]]}    {'val': 0, 'from': [[1, 1]]}             {'val': -2, 'from': [[2, 2], [1, 2]]}    {'val': 0, 'from': [[2, 3], [1, 3]]}     {'val': -2, 'from': [[2, 4]]}          {'val': -4, 'from': [[2, 5]]}            {'val': -6, 'from': [[2, 6]]}         {'val': -8, 'from': [[2, 7]]}          {'val': -10, 'from': [[2, 8], [1, 8]]}  {'val': -12, 'from': [[2, 9], [1, 9]]}  {'val': -14, 'from': [[2, 10], [1, 10]]}          {'val': -12, 'from': [[2, 11], [1, 11]]}
# A - 3   {'val': -6, 'from': [2, 0]}    {'val': -2, 'from': [[2, 1]]}   {'val': -2, 'from': [[2, 2], [2, 1]]}    {'val': 2, 'from': [[2, 2]]}             {'val': 0, 'from': [[3, 3]]}             {'val': -2, 'from': [[3, 4], [2, 4]]}  {'val': 0, 'from': [[3, 5], [2, 5]]}     {'val': -2, 'from': [[3, 6]]}         {'val': -4, 'from': [[3, 7]]}          {'val': -6, 'from': [[3, 8]]}           {'val': -4, 'from': [[3, 9]]}           {'val': -2, 'from': [[3, 10]]}                    {'val': -4, 'from': [[3, 11]]}
# A - 4   {'val': -8, 'from': [3, 0]}    {'val': -4, 'from': [[3, 1]]}   {'val': -4, 'from': [[3, 2], [3, 1]]}    {'val': 4, 'from': [[3, 3]]}             {'val': 2, 'from': [[4, 3]]}             {'val': 0, 'from': [[4, 4]]}           {'val': 2, 'from': [[3, 6], [4, 5]]}     {'val': 0, 'from': [[4, 6]]}          {'val': -2, 'from': [[4, 7]]}          {'val': -4, 'from': [[4, 8]]}           {'val': -2, 'from': [[3, 10], [4, 9]]}  {'val': 0, 'from': [[3, 11], [4, 10]]}            {'val': -2, 'from': [[4, 11]]}
# T - 5   {'val': -10, 'from': [4, 0]}   {'val': -6, 'from': [[4, 1]]}   {'val': -6, 'from': [[4, 2], [4, 1]]}    {'val': 2, 'from': [[4, 3]]}             {'val': 6, 'from': [[4, 3]]}             {'val': 4, 'from': [[5, 4]]}           {'val': 2, 'from': [[5, 5]]}             {'val': 0, 'from': [[5, 6], [4, 6]]}  {'val': -2, 'from': [[5, 7], [4, 7]]}  {'val': -4, 'from': [[5, 8], [4, 8]]}   {'val': -4, 'from': [[4, 10]]}          {'val': -2, 'from': [[4, 11]]}                    {'val': 2, 'from': [[4, 11]]}
# G - 6   {'val': -12, 'from': [5, 0]}   {'val': -4, 'from': [[5, 1]]}   {'val': -6, 'from': [[6, 1]]}            {'val': 0, 'from': [[5, 3]]}             {'val': 4, 'from': [[5, 4]]}             {'val': 4, 'from': [[5, 4]]}           {'val': 2, 'from': [[6, 5], [5, 5]]}     {'val': 0, 'from': [[6, 6], [5, 6]]}  {'val': 2, 'from': [[6, 7], [5, 7]]}   {'val': 0, 'from': [[6, 8]]}            {'val': -2, 'from': [[6, 9]]}           {'val': -4, 'from': [[5, 11], [6, 10]]}           {'val': 0, 'from': [[5, 12]]}
# G - 7   {'val': -14, 'from': [6, 0]}   {'val': -2, 'from': [[6, 1]]}   {'val': -4, 'from': [[7, 1]]}            {'val': -2, 'from': [[6, 3]]}            {'val': 2, 'from': [[6, 4]]}             {'val': 2, 'from': [[6, 5], [6, 4]]}   {'val': 2, 'from': [[6, 5]]}             {'val': 0, 'from': [[7, 6], [6, 6]]}  {'val': 4, 'from': [[6, 8]]}           {'val': 2, 'from': [[7, 8]]}            {'val': 0, 'from': [[7, 9]]}            {'val': -2, 'from': [[7, 10]]}                    {'val': -2, 'from': [[6, 12]]}
# A - 8   {'val': -16, 'from': [7, 0]}   {'val': -4, 'from': [[7, 1]]}   {'val': -4, 'from': [[7, 1]]}            {'val': 0, 'from': [[7, 3]]}             {'val': 0, 'from': [[7, 4]]}             {'val': 0, 'from': [[7, 5], [7, 4]]}   {'val': 4, 'from': [[7, 6], [7, 5]]}     {'val': 2, 'from': [[8, 6]]}          {'val': 2, 'from': [[7, 8]]}           {'val': 2, 'from': [[7, 8]]}            {'val': 4, 'from': [[8, 9], [7, 9]]}    {'val': 6, 'from': [[8, 10]]}                     {'val': 4, 'from': [[8, 11]]}
# C - 9   {'val': -18, 'from': [8, 0]}   {'val': -6, 'from': [[8, 1]]}   {'val': -2, 'from': [[8, 2], [8, 1]]}    {'val': -2, 'from': [[8, 3]]}            {'val': -2, 'from': [[8, 4], [8, 3]]}    {'val': 2, 'from': [[8, 5], [8, 4]]}   {'val': 2, 'from': [[8, 6]]}             {'val': 6, 'from': [[8, 6]]}          {'val': 4, 'from': [[9, 7]]}           {'val': 6, 'from': [[9, 8]]}            {'val': 4, 'from': [[9, 9]]}            {'val': 4, 'from': [[8, 11]]}                     {'val': 4, 'from': [[8, 11]]}
# G - 10  {'val': -20, 'from': [9, 0]}   {'val': -4, 'from': [[9, 1]]}   {'val': -4, 'from': [[9, 2]]}            {'val': -4, 'from': [[9, 3], [9, 2]]}    {'val': -4, 'from': [[9, 4], [9, 3]]}    {'val': 0, 'from': [[9, 5]]}           {'val': 0, 'from': [[9, 6], [9, 5]]}     {'val': 4, 'from': [[9, 7]]}          {'val': 8, 'from': [[9, 7]]}           {'val': 6, 'from': [[10, 8]]}           {'val': 4, 'from': [[10, 9], [9, 9]]}   {'val': 2, 'from': [[9, 11], [10, 10], [9, 10]]}  {'val': 2, 'from': [[9, 12], [9, 11]]}
# T - 11  {'val': -22, 'from': [10, 0]}  {'val': -6, 'from': [[10, 1]]}  {'val': -6, 'from': [[10, 2], [10, 1]]}  {'val': -6, 'from': [[10, 3], [10, 2]]}  {'val': -2, 'from': [[10, 4], [10, 3]]}  {'val': -2, 'from': [[10, 5]]}         {'val': -2, 'from': [[10, 6], [10, 5]]}  {'val': 2, 'from': [[10, 7]]}         {'val': 6, 'from': [[10, 8]]}          {'val': 6, 'from': [[10, 8]]}           {'val': 4, 'from': [[11, 9], [10, 9]]}  {'val': 2, 'from': [[11, 10], [10, 10]]}          {'val': 4, 'from': [[10, 12], [11, 11], [10, 11]]}
#
# 1 - 4
# -1      - - 0                          G - 1                           T - 2                                  G - 3                                 C - 4                                          T - 5                                          A - 6                                  C - 7                                   G - 8                                 C - 9                                  C - 10                                 G - 11
# - - 0   {'val': 0, 'from': None}       {'val': -2, 'from': [0, 0]}     {'val': -4, 'from': [0, 1]}            {'val': -6, 'from': [0, 2]}           {'val': -8, 'from': [0, 3]}                    {'val': -10, 'from': [0, 4]}                   {'val': -12, 'from': [0, 5]}           {'val': -14, 'from': [0, 6]}            {'val': -16, 'from': [0, 7]}          {'val': -18, 'from': [0, 8]}           {'val': -20, 'from': [0, 9]}           {'val': -22, 'from': [0, 10]}
# G - 1   {'val': -2, 'from': [0, 0]}    {'val': 2, 'from': [[0, 0]]}    {'val': 0, 'from': [[1, 1]]}           {'val': 2, 'from': [[1, 2]]}          {'val': 0, 'from': [[1, 3]]}                   {'val': -2, 'from': [[1, 4]]}                  {'val': -4, 'from': [[1, 5]]}          {'val': -6, 'from': [[1, 6]]}           {'val': -4, 'from': [[1, 7]]}         {'val': -6, 'from': [[1, 8]]}          {'val': -8, 'from': [[1, 9]]}          {'val': -6, 'from': [[1, 10]]}
# T - 2   {'val': -4, 'from': [1, 0]}    {'val': 0, 'from': [[1, 1]]}    {'val': 4, 'from': [[1, 1]]}           {'val': 2, 'from': [[2, 2]]}          {'val': 0, 'from': [[2, 3], [1, 3]]}           {'val': 2, 'from': [[2, 4], [1, 4]]}           {'val': 0, 'from': [[2, 5]]}           {'val': -2, 'from': [[2, 6]]}           {'val': -4, 'from': [[2, 7]]}         {'val': -6, 'from': [[2, 8], [1, 8]]}  {'val': -8, 'from': [[2, 9], [1, 9]]}  {'val': -8, 'from': [[1, 11]]}
# A - 3   {'val': -6, 'from': [2, 0]}    {'val': -2, 'from': [[2, 1]]}   {'val': 2, 'from': [[2, 2]]}           {'val': 2, 'from': [[2, 2]]}          {'val': 0, 'from': [[3, 3], [2, 3]]}           {'val': 0, 'from': [[2, 5]]}                   {'val': 4, 'from': [[2, 5]]}           {'val': 2, 'from': [[3, 6]]}            {'val': 0, 'from': [[3, 7]]}          {'val': -2, 'from': [[3, 8]]}          {'val': -4, 'from': [[3, 9]]}          {'val': -6, 'from': [[3, 10]]}
# A - 4   {'val': -8, 'from': [3, 0]}    {'val': -4, 'from': [[3, 1]]}   {'val': 0, 'from': [[3, 2]]}           {'val': 0, 'from': [[3, 3], [3, 2]]}  {'val': 0, 'from': [[3, 3]]}                   {'val': -2, 'from': [[3, 5], [4, 4], [3, 4]]}  {'val': 6, 'from': [[3, 6]]}           {'val': 4, 'from': [[4, 6]]}            {'val': 2, 'from': [[4, 7]]}          {'val': 0, 'from': [[4, 8]]}           {'val': -2, 'from': [[4, 9]]}          {'val': -4, 'from': [[4, 10]]}
# T - 5   {'val': -10, 'from': [4, 0]}   {'val': -6, 'from': [[4, 1]]}   {'val': 2, 'from': [[4, 2]]}           {'val': 0, 'from': [[5, 2]]}          {'val': -2, 'from': [[4, 4], [5, 3], [4, 3]]}  {'val': 2, 'from': [[4, 4]]}                   {'val': 4, 'from': [[4, 6]]}           {'val': 4, 'from': [[4, 6]]}            {'val': 2, 'from': [[5, 7], [4, 7]]}  {'val': 0, 'from': [[5, 8], [4, 8]]}   {'val': -2, 'from': [[5, 9], [4, 9]]}  {'val': -4, 'from': [[5, 10], [4, 10]]}
# G - 6   {'val': -12, 'from': [5, 0]}   {'val': -4, 'from': [[5, 1]]}   {'val': 0, 'from': [[5, 2]]}           {'val': 4, 'from': [[5, 2]]}          {'val': 2, 'from': [[6, 3]]}                   {'val': 0, 'from': [[5, 5], [6, 4]]}           {'val': 2, 'from': [[5, 6]]}           {'val': 2, 'from': [[5, 7], [5, 6]]}    {'val': 6, 'from': [[5, 7]]}          {'val': 4, 'from': [[6, 8]]}           {'val': 2, 'from': [[6, 9]]}           {'val': 4, 'from': [[6, 10]]}
# G - 7   {'val': -14, 'from': [6, 0]}   {'val': -2, 'from': [[6, 1]]}   {'val': -2, 'from': [[6, 2]]}          {'val': 6, 'from': [[6, 3]]}          {'val': 4, 'from': [[7, 3]]}                   {'val': 2, 'from': [[7, 4]]}                   {'val': 0, 'from': [[6, 6], [7, 5]]}   {'val': 0, 'from': [[6, 7], [6, 6]]}    {'val': 8, 'from': [[6, 8]]}          {'val': 6, 'from': [[7, 8]]}           {'val': 4, 'from': [[7, 9]]}           {'val': 6, 'from': [[6, 11], [7, 10]]}
# A - 8   {'val': -16, 'from': [7, 0]}   {'val': -4, 'from': [[7, 1]]}   {'val': -4, 'from': [[7, 2], [7, 1]]}  {'val': 4, 'from': [[7, 3]]}          {'val': 4, 'from': [[7, 3]]}                   {'val': 2, 'from': [[8, 4], [7, 4]]}           {'val': 4, 'from': [[8, 5], [7, 5]]}   {'val': 2, 'from': [[8, 6]]}            {'val': 6, 'from': [[7, 8]]}          {'val': 6, 'from': [[7, 8]]}           {'val': 4, 'from': [[8, 9], [7, 9]]}   {'val': 4, 'from': [[7, 11]]}
# C - 9   {'val': -18, 'from': [8, 0]}   {'val': -6, 'from': [[8, 1]]}   {'val': -6, 'from': [[8, 2], [8, 1]]}  {'val': 2, 'from': [[8, 3]]}          {'val': 6, 'from': [[8, 4], [8, 3]]}           {'val': 4, 'from': [[9, 4]]}                   {'val': 2, 'from': [[8, 6], [9, 5]]}   {'val': 6, 'from': [[8, 6]]}            {'val': 4, 'from': [[8, 8], [9, 7]]}  {'val': 8, 'from': [[8, 9], [8, 8]]}   {'val': 10, 'from': [[9, 9]]}          {'val': 8, 'from': [[9, 10]]}
# G - 10  {'val': -20, 'from': [9, 0]}   {'val': -4, 'from': [[9, 1]]}   {'val': -6, 'from': [[10, 1]]}         {'val': 4, 'from': [[9, 3]]}          {'val': 4, 'from': [[9, 4]]}                   {'val': 4, 'from': [[9, 4]]}                   {'val': 2, 'from': [[10, 5], [9, 5]]}  {'val': 4, 'from': [[9, 7]]}            {'val': 8, 'from': [[9, 7]]}          {'val': 6, 'from': [[9, 9], [10, 8]]}  {'val': 8, 'from': [[9, 10]]}          {'val': 12, 'from': [[9, 10]]}
# T - 11  {'val': -22, 'from': [10, 0]}  {'val': -6, 'from': [[10, 1]]}  {'val': -2, 'from': [[10, 1]]}         {'val': 2, 'from': [[10, 3]]}         {'val': 2, 'from': [[10, 4], [10, 3]]}         {'val': 6, 'from': [[10, 5], [10, 4]]}         {'val': 4, 'from': [[11, 5]]}          {'val': 2, 'from': [[10, 7], [11, 6]]}  {'val': 6, 'from': [[10, 8]]}         {'val': 6, 'from': [[10, 8]]}          {'val': 6, 'from': [[10, 10]]}         {'val': 10, 'from': [[10, 11]]}
#
# 1 - 5
# -1      - - 0                          G - 1                           G - 2                                   G - 3                                  A - 4                                    T - 5                                   G - 6                           C - 7                                    A - 8                                    C - 9                                  G - 10
# - - 0   {'val': 0, 'from': None}       {'val': -2, 'from': [0, 0]}     {'val': -4, 'from': [0, 1]}             {'val': -6, 'from': [0, 2]}            {'val': -8, 'from': [0, 3]}              {'val': -10, 'from': [0, 4]}            {'val': -12, 'from': [0, 5]}    {'val': -14, 'from': [0, 6]}             {'val': -16, 'from': [0, 7]}             {'val': -18, 'from': [0, 8]}           {'val': -20, 'from': [0, 9]}
# G - 1   {'val': -2, 'from': [0, 0]}    {'val': 2, 'from': [[0, 0]]}    {'val': 4, 'from': [[1, 1]]}            {'val': 6, 'from': [[1, 2]]}           {'val': 4, 'from': [[1, 3]]}             {'val': 2, 'from': [[1, 4]]}            {'val': 4, 'from': [[1, 5]]}    {'val': 2, 'from': [[1, 6]]}             {'val': 0, 'from': [[1, 7]]}             {'val': -2, 'from': [[1, 8]]}          {'val': 0, 'from': [[1, 9]]}
# T - 2   {'val': -4, 'from': [1, 0]}    {'val': 0, 'from': [[1, 1]]}    {'val': 2, 'from': [[1, 2]]}            {'val': 4, 'from': [[1, 3]]}           {'val': 4, 'from': [[1, 3]]}             {'val': 6, 'from': [[2, 4], [1, 4]]}    {'val': 4, 'from': [[2, 5]]}    {'val': 2, 'from': [[2, 6], [1, 6]]}     {'val': 0, 'from': [[2, 7], [1, 7]]}     {'val': -2, 'from': [[2, 8], [1, 8]]}  {'val': -2, 'from': [[1, 10]]}
# A - 3   {'val': -6, 'from': [2, 0]}    {'val': -2, 'from': [[2, 1]]}   {'val': 0, 'from': [[2, 2]]}            {'val': 2, 'from': [[2, 3]]}           {'val': 6, 'from': [[2, 4], [2, 3]]}     {'val': 4, 'from': [[2, 5], [3, 4]]}    {'val': 4, 'from': [[2, 5]]}    {'val': 2, 'from': [[3, 6], [2, 6]]}     {'val': 4, 'from': [[3, 7], [2, 7]]}     {'val': 2, 'from': [[3, 8]]}           {'val': 0, 'from': [[3, 9]]}
# A - 4   {'val': -8, 'from': [3, 0]}    {'val': -4, 'from': [[3, 1]]}   {'val': -2, 'from': [[3, 2]]}           {'val': 0, 'from': [[3, 3]]}           {'val': 8, 'from': [[3, 4]]}             {'val': 6, 'from': [[4, 4]]}            {'val': 4, 'from': [[4, 5]]}    {'val': 2, 'from': [[4, 6], [3, 6]]}     {'val': 6, 'from': [[3, 8]]}             {'val': 4, 'from': [[4, 8]]}           {'val': 2, 'from': [[4, 9]]}
# T - 5   {'val': -10, 'from': [4, 0]}   {'val': -6, 'from': [[4, 1]]}   {'val': -4, 'from': [[4, 2]]}           {'val': -2, 'from': [[4, 3]]}          {'val': 6, 'from': [[4, 4]]}             {'val': 10, 'from': [[4, 4]]}           {'val': 8, 'from': [[5, 5]]}    {'val': 6, 'from': [[5, 6]]}             {'val': 4, 'from': [[4, 8], [5, 7]]}     {'val': 4, 'from': [[4, 8]]}           {'val': 2, 'from': [[5, 9], [4, 9]]}
# G - 6   {'val': -12, 'from': [5, 0]}   {'val': -4, 'from': [[5, 1]]}   {'val': -2, 'from': [[5, 2], [6, 1]]}   {'val': 0, 'from': [[5, 3], [6, 2]]}   {'val': 4, 'from': [[5, 4]]}             {'val': 8, 'from': [[5, 5]]}            {'val': 12, 'from': [[5, 5]]}   {'val': 10, 'from': [[6, 6]]}            {'val': 8, 'from': [[6, 7]]}             {'val': 6, 'from': [[6, 8]]}           {'val': 8, 'from': [[6, 9]]}
# G - 7   {'val': -14, 'from': [6, 0]}   {'val': -2, 'from': [[6, 1]]}   {'val': 0, 'from': [[6, 2], [7, 1]]}    {'val': 2, 'from': [[6, 3], [7, 2]]}   {'val': 2, 'from': [[6, 4]]}             {'val': 6, 'from': [[6, 5]]}            {'val': 14, 'from': [[6, 6]]}   {'val': 12, 'from': [[7, 6]]}            {'val': 10, 'from': [[7, 7]]}            {'val': 8, 'from': [[7, 8]]}           {'val': 10, 'from': [[6, 10], [7, 9]]}
# A - 8   {'val': -16, 'from': [7, 0]}   {'val': -4, 'from': [[7, 1]]}   {'val': -2, 'from': [[7, 2]]}           {'val': 0, 'from': [[7, 3]]}           {'val': 4, 'from': [[7, 4], [7, 3]]}     {'val': 4, 'from': [[7, 5]]}            {'val': 12, 'from': [[7, 6]]}   {'val': 12, 'from': [[7, 6]]}            {'val': 14, 'from': [[8, 7], [7, 7]]}    {'val': 12, 'from': [[8, 8]]}          {'val': 10, 'from': [[8, 9]]}
# C - 9   {'val': -18, 'from': [8, 0]}   {'val': -6, 'from': [[8, 1]]}   {'val': -4, 'from': [[8, 2]]}           {'val': -2, 'from': [[8, 3]]}          {'val': 2, 'from': [[8, 4]]}             {'val': 2, 'from': [[8, 5], [8, 4]]}    {'val': 10, 'from': [[8, 6]]}   {'val': 14, 'from': [[8, 7], [8, 6]]}    {'val': 12, 'from': [[8, 8], [9, 7]]}    {'val': 16, 'from': [[8, 8]]}          {'val': 14, 'from': [[9, 9]]}
# G - 10  {'val': -20, 'from': [9, 0]}   {'val': -4, 'from': [[9, 1]]}   {'val': -2, 'from': [[9, 2], [10, 1]]}  {'val': 0, 'from': [[9, 3], [10, 2]]}  {'val': 0, 'from': [[9, 4]]}             {'val': 0, 'from': [[9, 5], [9, 4]]}    {'val': 12, 'from': [[9, 6]]}   {'val': 12, 'from': [[9, 7]]}            {'val': 12, 'from': [[9, 7]]}            {'val': 14, 'from': [[9, 9]]}          {'val': 18, 'from': [[9, 9]]}
# T - 11  {'val': -22, 'from': [10, 0]}  {'val': -6, 'from': [[10, 1]]}  {'val': -4, 'from': [[10, 2]]}          {'val': -2, 'from': [[10, 3]]}         {'val': -2, 'from': [[10, 4], [10, 3]]}  {'val': 2, 'from': [[10, 5], [10, 4]]}  {'val': 10, 'from': [[10, 6]]}  {'val': 10, 'from': [[10, 7], [10, 6]]}  {'val': 10, 'from': [[10, 8], [10, 7]]}  {'val': 12, 'from': [[10, 9]]}         {'val': 16, 'from': [[10, 10]]}
#
# 2 - 3
# -1     - - 0                         G - 1                          C - 2                                  A - 3                                          T - 4                                 C - 5                                 A - 6                                 C - 7                                          G - 8                                         C - 9                                 A - 10                                          A - 11                                   T - 12
# - - 0  {'val': 0, 'from': None}      {'val': -2, 'from': [0, 0]}    {'val': -4, 'from': [0, 1]}            {'val': -6, 'from': [0, 2]}                    {'val': -8, 'from': [0, 3]}           {'val': -10, 'from': [0, 4]}          {'val': -12, 'from': [0, 5]}          {'val': -14, 'from': [0, 6]}                   {'val': -16, 'from': [0, 7]}                  {'val': -18, 'from': [0, 8]}          {'val': -20, 'from': [0, 9]}                    {'val': -22, 'from': [0, 10]}            {'val': -24, 'from': [0, 11]}
# G - 1  {'val': -2, 'from': [0, 0]}   {'val': 2, 'from': [[0, 0]]}   {'val': 0, 'from': [[1, 1]]}           {'val': -2, 'from': [[1, 2]]}                  {'val': -4, 'from': [[1, 3]]}         {'val': -6, 'from': [[1, 4]]}         {'val': -8, 'from': [[1, 5]]}         {'val': -10, 'from': [[1, 6]]}                 {'val': -8, 'from': [[1, 7]]}                 {'val': -10, 'from': [[1, 8]]}        {'val': -12, 'from': [[1, 9]]}                  {'val': -14, 'from': [[1, 10]]}          {'val': -16, 'from': [[1, 11]]}
# C - 2  {'val': -4, 'from': [1, 0]}   {'val': 0, 'from': [[1, 1]]}   {'val': 4, 'from': [[1, 1]]}           {'val': 2, 'from': [[2, 2]]}                   {'val': 0, 'from': [[2, 3]]}          {'val': 2, 'from': [[2, 4]]}          {'val': 0, 'from': [[2, 5]]}          {'val': 2, 'from': [[2, 6]]}                   {'val': 0, 'from': [[2, 7]]}                  {'val': 2, 'from': [[2, 8]]}          {'val': 0, 'from': [[2, 9]]}                    {'val': -2, 'from': [[2, 10]]}           {'val': -4, 'from': [[2, 11]]}
# G - 3  {'val': -6, 'from': [2, 0]}   {'val': 2, 'from': [[2, 1]]}   {'val': 2, 'from': [[2, 2]]}           {'val': 2, 'from': [[2, 2]]}                   {'val': 0, 'from': [[3, 3], [2, 3]]}  {'val': 0, 'from': [[2, 5]]}          {'val': 0, 'from': [[2, 5]]}          {'val': 0, 'from': [[2, 7]]}                   {'val': 4, 'from': [[2, 7]]}                  {'val': 2, 'from': [[3, 8]]}          {'val': 0, 'from': [[3, 9], [2, 9]]}            {'val': -2, 'from': [[3, 10], [2, 10]]}  {'val': -4, 'from': [[3, 11], [2, 11]]}
# T - 4  {'val': -8, 'from': [3, 0]}   {'val': 0, 'from': [[3, 1]]}   {'val': 0, 'from': [[3, 2], [3, 1]]}   {'val': 0, 'from': [[3, 3], [3, 2]]}           {'val': 4, 'from': [[3, 3]]}          {'val': 2, 'from': [[4, 4]]}          {'val': 0, 'from': [[4, 5]]}          {'val': -2, 'from': [[3, 7], [4, 6], [3, 6]]}  {'val': 2, 'from': [[3, 8]]}                  {'val': 2, 'from': [[3, 8]]}          {'val': 0, 'from': [[4, 9], [3, 9]]}            {'val': -2, 'from': [[4, 10], [3, 10]]}  {'val': 0, 'from': [[4, 11], [3, 11]]}
# T - 5  {'val': -10, 'from': [4, 0]}  {'val': -2, 'from': [[4, 1]]}  {'val': -2, 'from': [[4, 2], [4, 1]]}  {'val': -2, 'from': [[4, 3], [4, 2]]}          {'val': 6, 'from': [[4, 4]]}          {'val': 4, 'from': [[5, 4]]}          {'val': 2, 'from': [[5, 5]]}          {'val': 0, 'from': [[5, 6]]}                   {'val': 0, 'from': [[4, 8]]}                  {'val': 0, 'from': [[4, 9], [4, 8]]}  {'val': 0, 'from': [[4, 9]]}                    {'val': -2, 'from': [[5, 10], [4, 10]]}  {'val': 2, 'from': [[4, 12]]}
# G - 6  {'val': -12, 'from': [5, 0]}  {'val': 0, 'from': [[5, 1]]}   {'val': -2, 'from': [[6, 1]]}          {'val': -4, 'from': [[5, 3], [6, 2], [5, 2]]}  {'val': 4, 'from': [[5, 4]]}          {'val': 4, 'from': [[5, 4]]}          {'val': 2, 'from': [[6, 5], [5, 5]]}  {'val': 0, 'from': [[6, 6], [5, 6]]}           {'val': 2, 'from': [[5, 8], [6, 7], [5, 7]]}  {'val': 0, 'from': [[6, 8]]}          {'val': -2, 'from': [[5, 10], [6, 9], [5, 9]]}  {'val': -2, 'from': [[5, 10]]}           {'val': 0, 'from': [[5, 12]]}
# C - 7  {'val': -14, 'from': [6, 0]}  {'val': -2, 'from': [[6, 1]]}  {'val': 2, 'from': [[6, 1]]}           {'val': 0, 'from': [[7, 2]]}                   {'val': 2, 'from': [[6, 4]]}          {'val': 6, 'from': [[6, 5], [6, 4]]}  {'val': 4, 'from': [[7, 5]]}          {'val': 6, 'from': [[7, 6]]}                   {'val': 4, 'from': [[7, 7]]}                  {'val': 6, 'from': [[7, 8]]}          {'val': 4, 'from': [[7, 9]]}                    {'val': 2, 'from': [[7, 10]]}            {'val': 0, 'from': [[7, 11]]}
# G - 8  {'val': -16, 'from': [7, 0]}  {'val': 0, 'from': [[7, 1]]}   {'val': 0, 'from': [[7, 2]]}           {'val': 0, 'from': [[7, 2]]}                   {'val': 0, 'from': [[7, 4]]}          {'val': 4, 'from': [[7, 5]]}          {'val': 4, 'from': [[7, 5]]}          {'val': 4, 'from': [[7, 7]]}                   {'val': 8, 'from': [[7, 7]]}                  {'val': 6, 'from': [[8, 8]]}          {'val': 4, 'from': [[8, 9], [7, 9]]}            {'val': 2, 'from': [[8, 10], [7, 10]]}   {'val': 0, 'from': [[8, 11], [7, 11]]}
# T - 9  {'val': -18, 'from': [8, 0]}  {'val': -2, 'from': [[8, 1]]}  {'val': -2, 'from': [[8, 2], [8, 1]]}  {'val': -2, 'from': [[8, 3], [8, 2]]}          {'val': 2, 'from': [[8, 4], [8, 3]]}  {'val': 2, 'from': [[8, 5]]}          {'val': 2, 'from': [[8, 6], [8, 5]]}  {'val': 2, 'from': [[8, 7], [8, 6]]}           {'val': 6, 'from': [[8, 8]]}                  {'val': 6, 'from': [[8, 8]]}          {'val': 4, 'from': [[9, 9], [8, 9]]}            {'val': 2, 'from': [[9, 10], [8, 10]]}   {'val': 4, 'from': [[9, 11], [8, 11]]}
#
# 2 - 4
# -1     - - 0                         G - 1                          T - 2                                 G - 3                                         C - 4                                         T - 5                                  A - 6                                 C - 7                                 G - 8                                 C - 9                                 C - 10                                         G - 11
# - - 0  {'val': 0, 'from': None}      {'val': -2, 'from': [0, 0]}    {'val': -4, 'from': [0, 1]}           {'val': -6, 'from': [0, 2]}                   {'val': -8, 'from': [0, 3]}                   {'val': -10, 'from': [0, 4]}           {'val': -12, 'from': [0, 5]}          {'val': -14, 'from': [0, 6]}          {'val': -16, 'from': [0, 7]}          {'val': -18, 'from': [0, 8]}          {'val': -20, 'from': [0, 9]}                   {'val': -22, 'from': [0, 10]}
# G - 1  {'val': -2, 'from': [0, 0]}   {'val': 2, 'from': [[0, 0]]}   {'val': 0, 'from': [[1, 1]]}          {'val': 2, 'from': [[1, 2]]}                  {'val': 0, 'from': [[1, 3]]}                  {'val': -2, 'from': [[1, 4]]}          {'val': -4, 'from': [[1, 5]]}         {'val': -6, 'from': [[1, 6]]}         {'val': -4, 'from': [[1, 7]]}         {'val': -6, 'from': [[1, 8]]}         {'val': -8, 'from': [[1, 9]]}                  {'val': -6, 'from': [[1, 10]]}
# C - 2  {'val': -4, 'from': [1, 0]}   {'val': 0, 'from': [[1, 1]]}   {'val': 0, 'from': [[1, 1]]}          {'val': 0, 'from': [[1, 3]]}                  {'val': 4, 'from': [[1, 3]]}                  {'val': 2, 'from': [[2, 4]]}           {'val': 0, 'from': [[2, 5]]}          {'val': 2, 'from': [[2, 6]]}          {'val': 0, 'from': [[2, 7]]}          {'val': 2, 'from': [[2, 8]]}          {'val': 4, 'from': [[2, 9]]}                   {'val': 2, 'from': [[2, 10]]}
# G - 3  {'val': -6, 'from': [2, 0]}   {'val': 2, 'from': [[2, 1]]}   {'val': 0, 'from': [[3, 1]]}          {'val': 2, 'from': [[2, 3], [3, 2], [2, 2]]}  {'val': 2, 'from': [[2, 4]]}                  {'val': 2, 'from': [[2, 4]]}           {'val': 0, 'from': [[3, 5], [2, 5]]}  {'val': 0, 'from': [[2, 7]]}          {'val': 4, 'from': [[2, 7]]}          {'val': 2, 'from': [[3, 8]]}          {'val': 2, 'from': [[2, 10]]}                  {'val': 6, 'from': [[2, 10]]}
# T - 4  {'val': -8, 'from': [3, 0]}   {'val': 0, 'from': [[3, 1]]}   {'val': 4, 'from': [[3, 1]]}          {'val': 2, 'from': [[4, 2]]}                  {'val': 0, 'from': [[3, 4], [4, 3], [3, 3]]}  {'val': 4, 'from': [[3, 5], [3, 4]]}   {'val': 2, 'from': [[4, 5]]}          {'val': 0, 'from': [[4, 6]]}          {'val': 2, 'from': [[3, 8]]}          {'val': 2, 'from': [[3, 8]]}          {'val': 0, 'from': [[3, 10], [4, 9], [3, 9]]}  {'val': 4, 'from': [[3, 11]]}
# T - 5  {'val': -10, 'from': [4, 0]}  {'val': -2, 'from': [[4, 1]]}  {'val': 6, 'from': [[4, 2]]}          {'val': 4, 'from': [[5, 2]]}                  {'val': 2, 'from': [[5, 3]]}                  {'val': 6, 'from': [[4, 5]]}           {'val': 4, 'from': [[5, 5]]}          {'val': 2, 'from': [[5, 6]]}          {'val': 0, 'from': [[4, 8], [5, 7]]}  {'val': 0, 'from': [[4, 9], [4, 8]]}  {'val': 0, 'from': [[4, 9]]}                   {'val': 2, 'from': [[4, 11]]}
# G - 6  {'val': -12, 'from': [5, 0]}  {'val': 0, 'from': [[5, 1]]}   {'val': 4, 'from': [[5, 2]]}          {'val': 8, 'from': [[5, 2]]}                  {'val': 6, 'from': [[6, 3]]}                  {'val': 4, 'from': [[5, 5], [6, 4]]}   {'val': 4, 'from': [[5, 5]]}          {'val': 2, 'from': [[6, 6], [5, 6]]}  {'val': 4, 'from': [[6, 7], [5, 7]]}  {'val': 2, 'from': [[6, 8]]}          {'val': 0, 'from': [[6, 9]]}                   {'val': 4, 'from': [[5, 11]]}
# C - 7  {'val': -14, 'from': [6, 0]}  {'val': -2, 'from': [[6, 1]]}  {'val': 2, 'from': [[6, 2]]}          {'val': 6, 'from': [[6, 3]]}                  {'val': 10, 'from': [[6, 3]]}                 {'val': 8, 'from': [[7, 4]]}           {'val': 6, 'from': [[7, 5]]}          {'val': 8, 'from': [[7, 6]]}          {'val': 6, 'from': [[7, 7]]}          {'val': 8, 'from': [[7, 8]]}          {'val': 10, 'from': [[7, 9]]}                  {'val': 8, 'from': [[7, 10]]}
# G - 8  {'val': -16, 'from': [7, 0]}  {'val': 0, 'from': [[7, 1]]}   {'val': 0, 'from': [[7, 2]]}          {'val': 8, 'from': [[7, 3]]}                  {'val': 8, 'from': [[7, 4]]}                  {'val': 8, 'from': [[7, 4]]}           {'val': 6, 'from': [[8, 5], [7, 5]]}  {'val': 6, 'from': [[7, 7]]}          {'val': 10, 'from': [[7, 7]]}         {'val': 8, 'from': [[8, 8]]}          {'val': 8, 'from': [[7, 10]]}                  {'val': 12, 'from': [[7, 10]]}
# T - 9  {'val': -18, 'from': [8, 0]}  {'val': -2, 'from': [[8, 1]]}  {'val': 2, 'from': [[8, 2], [8, 1]]}  {'val': 6, 'from': [[8, 3]]}                  {'val': 6, 'from': [[8, 4], [8, 3]]}          {'val': 10, 'from': [[8, 5], [8, 4]]}  {'val': 8, 'from': [[9, 5]]}          {'val': 6, 'from': [[9, 6]]}          {'val': 8, 'from': [[8, 8]]}          {'val': 8, 'from': [[8, 8]]}          {'val': 6, 'from': [[8, 10], [9, 9], [8, 9]]}  {'val': 10, 'from': [[8, 11]]}
#
# 2 - 5
# -1     - - 0                         G - 1                          G - 2                                 G - 3                                 A - 4                                 T - 5                                         G - 6                                         C - 7                                         A - 8                                 C - 9                                         G - 10
# - - 0  {'val': 0, 'from': None}      {'val': -2, 'from': [0, 0]}    {'val': -4, 'from': [0, 1]}           {'val': -6, 'from': [0, 2]}           {'val': -8, 'from': [0, 3]}           {'val': -10, 'from': [0, 4]}                  {'val': -12, 'from': [0, 5]}                  {'val': -14, 'from': [0, 6]}                  {'val': -16, 'from': [0, 7]}          {'val': -18, 'from': [0, 8]}                  {'val': -20, 'from': [0, 9]}
# G - 1  {'val': -2, 'from': [0, 0]}   {'val': 2, 'from': [[0, 0]]}   {'val': 4, 'from': [[1, 1]]}          {'val': 6, 'from': [[1, 2]]}          {'val': 4, 'from': [[1, 3]]}          {'val': 2, 'from': [[1, 4]]}                  {'val': 4, 'from': [[1, 5]]}                  {'val': 2, 'from': [[1, 6]]}                  {'val': 0, 'from': [[1, 7]]}          {'val': -2, 'from': [[1, 8]]}                 {'val': 0, 'from': [[1, 9]]}
# C - 2  {'val': -4, 'from': [1, 0]}   {'val': 0, 'from': [[1, 1]]}   {'val': 2, 'from': [[1, 2]]}          {'val': 4, 'from': [[1, 3]]}          {'val': 4, 'from': [[1, 3]]}          {'val': 2, 'from': [[2, 4], [1, 4]]}          {'val': 2, 'from': [[1, 6]]}                  {'val': 6, 'from': [[1, 6]]}                  {'val': 4, 'from': [[2, 7]]}          {'val': 6, 'from': [[2, 8]]}                  {'val': 4, 'from': [[2, 9]]}
# G - 3  {'val': -6, 'from': [2, 0]}   {'val': 2, 'from': [[2, 1]]}   {'val': 4, 'from': [[2, 2], [3, 1]]}  {'val': 6, 'from': [[2, 3], [3, 2]]}  {'val': 4, 'from': [[3, 3]]}          {'val': 2, 'from': [[3, 4], [2, 4]]}          {'val': 4, 'from': [[2, 6], [3, 5], [2, 5]]}  {'val': 4, 'from': [[2, 7]]}                  {'val': 4, 'from': [[2, 7]]}          {'val': 4, 'from': [[2, 9]]}                  {'val': 8, 'from': [[2, 9]]}
# T - 4  {'val': -8, 'from': [3, 0]}   {'val': 0, 'from': [[3, 1]]}   {'val': 2, 'from': [[3, 2]]}          {'val': 4, 'from': [[3, 3]]}          {'val': 4, 'from': [[3, 3]]}          {'val': 6, 'from': [[4, 4], [3, 4]]}          {'val': 4, 'from': [[4, 5]]}                  {'val': 2, 'from': [[3, 7], [4, 6], [3, 6]]}  {'val': 2, 'from': [[3, 8], [3, 7]]}  {'val': 2, 'from': [[3, 9], [3, 8]]}          {'val': 6, 'from': [[3, 10]]}
# T - 5  {'val': -10, 'from': [4, 0]}  {'val': -2, 'from': [[4, 1]]}  {'val': 0, 'from': [[4, 2]]}          {'val': 2, 'from': [[4, 3]]}          {'val': 2, 'from': [[4, 4], [4, 3]]}  {'val': 8, 'from': [[4, 5]]}                  {'val': 6, 'from': [[5, 5]]}                  {'val': 4, 'from': [[5, 6]]}                  {'val': 2, 'from': [[5, 7]]}          {'val': 0, 'from': [[4, 9], [5, 8], [4, 8]]}  {'val': 4, 'from': [[4, 10]]}
# G - 6  {'val': -12, 'from': [5, 0]}  {'val': 0, 'from': [[5, 1]]}   {'val': 2, 'from': [[5, 2], [6, 1]]}  {'val': 4, 'from': [[5, 3], [6, 2]]}  {'val': 2, 'from': [[6, 3]]}          {'val': 6, 'from': [[5, 5]]}                  {'val': 10, 'from': [[5, 5]]}                 {'val': 8, 'from': [[6, 6]]}                  {'val': 6, 'from': [[6, 7]]}          {'val': 4, 'from': [[6, 8]]}                  {'val': 6, 'from': [[5, 10], [6, 9]]}
# C - 7  {'val': -14, 'from': [6, 0]}  {'val': -2, 'from': [[6, 1]]}  {'val': 0, 'from': [[6, 2]]}          {'val': 2, 'from': [[6, 3]]}          {'val': 2, 'from': [[6, 3]]}          {'val': 4, 'from': [[6, 5]]}                  {'val': 8, 'from': [[6, 6]]}                  {'val': 12, 'from': [[6, 6]]}                 {'val': 10, 'from': [[7, 7]]}         {'val': 12, 'from': [[7, 8]]}                 {'val': 10, 'from': [[7, 9]]}
# G - 8  {'val': -16, 'from': [7, 0]}  {'val': 0, 'from': [[7, 1]]}   {'val': 2, 'from': [[7, 2], [8, 1]]}  {'val': 4, 'from': [[7, 3], [8, 2]]}  {'val': 2, 'from': [[8, 3]]}          {'val': 2, 'from': [[7, 5]]}                  {'val': 10, 'from': [[7, 6]]}                 {'val': 10, 'from': [[7, 7]]}                 {'val': 10, 'from': [[7, 7]]}         {'val': 10, 'from': [[7, 9]]}                 {'val': 14, 'from': [[7, 9]]}
# T - 9  {'val': -18, 'from': [8, 0]}  {'val': -2, 'from': [[8, 1]]}  {'val': 0, 'from': [[8, 2]]}          {'val': 2, 'from': [[8, 3]]}          {'val': 2, 'from': [[8, 3]]}          {'val': 4, 'from': [[8, 5], [9, 4], [8, 4]]}  {'val': 8, 'from': [[8, 6]]}                  {'val': 8, 'from': [[8, 7], [8, 6]]}          {'val': 8, 'from': [[8, 8], [8, 7]]}  {'val': 8, 'from': [[8, 9], [8, 8]]}          {'val': 12, 'from': [[8, 10]]}
#
# 3 - 4
# -1      - - 0                          G - 1                            T - 2                                     G - 3                                  C - 4                           T - 5                                    A - 6                                          C - 7                                         G - 8                                            C - 9                                          C - 10                          G - 11
# - - 0   {'val': 0, 'from': None}       {'val': -2, 'from': [0, 0]}      {'val': -4, 'from': [0, 1]}               {'val': -6, 'from': [0, 2]}            {'val': -8, 'from': [0, 3]}     {'val': -10, 'from': [0, 4]}             {'val': -12, 'from': [0, 5]}                   {'val': -14, 'from': [0, 6]}                  {'val': -16, 'from': [0, 7]}                     {'val': -18, 'from': [0, 8]}                   {'val': -20, 'from': [0, 9]}    {'val': -22, 'from': [0, 10]}
# G - 1   {'val': -2, 'from': [0, 0]}    {'val': 2, 'from': [[0, 0]]}     {'val': 0, 'from': [[1, 1]]}              {'val': 2, 'from': [[1, 2]]}           {'val': 0, 'from': [[1, 3]]}    {'val': -2, 'from': [[1, 4]]}            {'val': -4, 'from': [[1, 5]]}                  {'val': -6, 'from': [[1, 6]]}                 {'val': -4, 'from': [[1, 7]]}                    {'val': -6, 'from': [[1, 8]]}                  {'val': -8, 'from': [[1, 9]]}   {'val': -6, 'from': [[1, 10]]}
# C - 2   {'val': -4, 'from': [1, 0]}    {'val': 0, 'from': [[1, 1]]}     {'val': 0, 'from': [[1, 1]]}              {'val': 0, 'from': [[1, 3]]}           {'val': 4, 'from': [[1, 3]]}    {'val': 2, 'from': [[2, 4]]}             {'val': 0, 'from': [[2, 5]]}                   {'val': 2, 'from': [[2, 6]]}                  {'val': 0, 'from': [[2, 7]]}                     {'val': 2, 'from': [[2, 8]]}                   {'val': 4, 'from': [[2, 9]]}    {'val': 2, 'from': [[2, 10]]}
# A - 3   {'val': -6, 'from': [2, 0]}    {'val': -2, 'from': [[2, 1]]}    {'val': -2, 'from': [[2, 2], [2, 1]]}     {'val': -2, 'from': [[2, 3], [2, 2]]}  {'val': 2, 'from': [[2, 4]]}    {'val': 2, 'from': [[2, 4]]}             {'val': 4, 'from': [[3, 5], [2, 5]]}           {'val': 2, 'from': [[3, 6]]}                  {'val': 0, 'from': [[3, 7], [2, 7]]}             {'val': 0, 'from': [[2, 9]]}                   {'val': 2, 'from': [[2, 10]]}   {'val': 2, 'from': [[2, 10]]}
# T - 4   {'val': -8, 'from': [3, 0]}    {'val': -4, 'from': [[3, 1]]}    {'val': 0, 'from': [[3, 2], [3, 1]]}      {'val': -2, 'from': [[4, 2]]}          {'val': 0, 'from': [[3, 4]]}    {'val': 4, 'from': [[3, 5], [3, 4]]}     {'val': 2, 'from': [[3, 6], [4, 5]]}           {'val': 2, 'from': [[3, 6]]}                  {'val': 0, 'from': [[4, 7], [3, 7]]}             {'val': -2, 'from': [[3, 9], [4, 8], [3, 8]]}  {'val': 0, 'from': [[3, 10]]}   {'val': 0, 'from': [[3, 11], [3, 10]]}
# C - 5   {'val': -10, 'from': [4, 0]}   {'val': -6, 'from': [[4, 1]]}    {'val': -2, 'from': [[4, 2]]}             {'val': -2, 'from': [[4, 2]]}          {'val': 2, 'from': [[4, 4]]}    {'val': 2, 'from': [[4, 5]]}             {'val': 2, 'from': [[4, 5]]}                   {'val': 4, 'from': [[4, 7], [5, 6], [4, 6]]}  {'val': 2, 'from': [[5, 7]]}                     {'val': 4, 'from': [[5, 8]]}                   {'val': 6, 'from': [[5, 9]]}    {'val': 4, 'from': [[5, 10]]}
# A - 6   {'val': -12, 'from': [5, 0]}   {'val': -8, 'from': [[5, 1]]}    {'val': -4, 'from': [[5, 2]]}             {'val': -4, 'from': [[5, 3], [5, 2]]}  {'val': 0, 'from': [[5, 4]]}    {'val': 0, 'from': [[5, 5], [5, 4]]}     {'val': 4, 'from': [[5, 6], [5, 5]]}           {'val': 2, 'from': [[5, 7], [6, 6]]}          {'val': 2, 'from': [[5, 7]]}                     {'val': 2, 'from': [[5, 9]]}                   {'val': 4, 'from': [[5, 10]]}   {'val': 4, 'from': [[5, 10]]}
# C - 7   {'val': -14, 'from': [6, 0]}   {'val': -10, 'from': [[6, 1]]}   {'val': -6, 'from': [[6, 2]]}             {'val': -6, 'from': [[6, 3], [6, 2]]}  {'val': 2, 'from': [[6, 4]]}    {'val': 0, 'from': [[7, 4]]}             {'val': 2, 'from': [[6, 6]]}                   {'val': 6, 'from': [[6, 6]]}                  {'val': 4, 'from': [[7, 7]]}                     {'val': 6, 'from': [[7, 8]]}                   {'val': 8, 'from': [[7, 9]]}    {'val': 6, 'from': [[7, 10]]}
# G - 8   {'val': -16, 'from': [7, 0]}   {'val': -8, 'from': [[7, 1]]}    {'val': -8, 'from': [[7, 2]]}             {'val': -4, 'from': [[7, 3], [7, 2]]}  {'val': 0, 'from': [[7, 4]]}    {'val': 0, 'from': [[7, 4]]}             {'val': 0, 'from': [[7, 6]]}                   {'val': 4, 'from': [[7, 7]]}                  {'val': 8, 'from': [[7, 7]]}                     {'val': 6, 'from': [[8, 8]]}                   {'val': 6, 'from': [[7, 10]]}   {'val': 10, 'from': [[7, 10]]}
# C - 9   {'val': -18, 'from': [8, 0]}   {'val': -10, 'from': [[8, 1]]}   {'val': -10, 'from': [[8, 2], [8, 1]]}    {'val': -6, 'from': [[8, 3]]}          {'val': 2, 'from': [[8, 4]]}    {'val': 0, 'from': [[9, 4]]}             {'val': -2, 'from': [[8, 6], [9, 5], [8, 5]]}  {'val': 6, 'from': [[8, 7]]}                  {'val': 6, 'from': [[8, 8]]}                     {'val': 10, 'from': [[8, 8]]}                  {'val': 12, 'from': [[9, 9]]}   {'val': 10, 'from': [[9, 10]]}
# A - 10  {'val': -20, 'from': [9, 0]}   {'val': -12, 'from': [[9, 1]]}   {'val': -12, 'from': [[9, 2], [9, 1]]}    {'val': -8, 'from': [[9, 3]]}          {'val': 0, 'from': [[9, 4]]}    {'val': 0, 'from': [[9, 4]]}             {'val': 2, 'from': [[10, 5], [9, 5]]}          {'val': 4, 'from': [[9, 7]]}                  {'val': 4, 'from': [[9, 8], [9, 7]]}             {'val': 8, 'from': [[9, 9]]}                   {'val': 10, 'from': [[9, 10]]}  {'val': 10, 'from': [[9, 10]]}
# A - 11  {'val': -22, 'from': [10, 0]}  {'val': -14, 'from': [[10, 1]]}  {'val': -14, 'from': [[10, 2], [10, 1]]}  {'val': -10, 'from': [[10, 3]]}        {'val': -2, 'from': [[10, 4]]}  {'val': -2, 'from': [[10, 5], [10, 4]]}  {'val': 4, 'from': [[10, 6]]}                  {'val': 2, 'from': [[10, 7], [11, 6]]}        {'val': 2, 'from': [[10, 8], [10, 7]]}           {'val': 6, 'from': [[10, 9]]}                  {'val': 8, 'from': [[10, 10]]}  {'val': 8, 'from': [[10, 11], [10, 10]]}
# T - 12  {'val': -24, 'from': [11, 0]}  {'val': -16, 'from': [[11, 1]]}  {'val': -12, 'from': [[11, 2], [11, 1]]}  {'val': -12, 'from': [[11, 3]]}        {'val': -4, 'from': [[11, 4]]}  {'val': 0, 'from': [[11, 5], [11, 4]]}   {'val': 2, 'from': [[11, 6]]}                  {'val': 2, 'from': [[11, 6]]}                 {'val': 0, 'from': [[11, 8], [12, 7], [11, 7]]}  {'val': 4, 'from': [[11, 9]]}                  {'val': 6, 'from': [[11, 10]]}  {'val': 6, 'from': [[11, 11], [11, 10]]}
#
# 3 - 5
# -1      - - 0                          G - 1                            G - 2                                  G - 3                                  A - 4                                 T - 5                                  G - 6                                    C - 7                                 A - 8                                 C - 9                                         G - 10
# - - 0   {'val': 0, 'from': None}       {'val': -2, 'from': [0, 0]}      {'val': -4, 'from': [0, 1]}            {'val': -6, 'from': [0, 2]}            {'val': -8, 'from': [0, 3]}           {'val': -10, 'from': [0, 4]}           {'val': -12, 'from': [0, 5]}             {'val': -14, 'from': [0, 6]}          {'val': -16, 'from': [0, 7]}          {'val': -18, 'from': [0, 8]}                  {'val': -20, 'from': [0, 9]}
# G - 1   {'val': -2, 'from': [0, 0]}    {'val': 2, 'from': [[0, 0]]}     {'val': 4, 'from': [[1, 1]]}           {'val': 6, 'from': [[1, 2]]}           {'val': 4, 'from': [[1, 3]]}          {'val': 2, 'from': [[1, 4]]}           {'val': 4, 'from': [[1, 5]]}             {'val': 2, 'from': [[1, 6]]}          {'val': 0, 'from': [[1, 7]]}          {'val': -2, 'from': [[1, 8]]}                 {'val': 0, 'from': [[1, 9]]}
# C - 2   {'val': -4, 'from': [1, 0]}    {'val': 0, 'from': [[1, 1]]}     {'val': 2, 'from': [[1, 2]]}           {'val': 4, 'from': [[1, 3]]}           {'val': 4, 'from': [[1, 3]]}          {'val': 2, 'from': [[2, 4], [1, 4]]}   {'val': 2, 'from': [[1, 6]]}             {'val': 6, 'from': [[1, 6]]}          {'val': 4, 'from': [[2, 7]]}          {'val': 6, 'from': [[2, 8]]}                  {'val': 4, 'from': [[2, 9]]}
# A - 3   {'val': -6, 'from': [2, 0]}    {'val': -2, 'from': [[2, 1]]}    {'val': 0, 'from': [[2, 2]]}           {'val': 2, 'from': [[2, 3]]}           {'val': 6, 'from': [[2, 4], [2, 3]]}  {'val': 4, 'from': [[3, 4]]}           {'val': 2, 'from': [[3, 5]]}             {'val': 4, 'from': [[2, 7]]}          {'val': 8, 'from': [[2, 7]]}          {'val': 6, 'from': [[3, 8]]}                  {'val': 4, 'from': [[3, 9], [2, 9]]}
# T - 4   {'val': -8, 'from': [3, 0]}    {'val': -4, 'from': [[3, 1]]}    {'val': -2, 'from': [[3, 2]]}          {'val': 0, 'from': [[3, 3]]}           {'val': 4, 'from': [[3, 4]]}          {'val': 8, 'from': [[3, 4]]}           {'val': 6, 'from': [[4, 5]]}             {'val': 4, 'from': [[4, 6]]}          {'val': 6, 'from': [[3, 8]]}          {'val': 6, 'from': [[3, 8]]}                  {'val': 4, 'from': [[4, 9], [3, 9]]}
# C - 5   {'val': -10, 'from': [4, 0]}   {'val': -6, 'from': [[4, 1]]}    {'val': -4, 'from': [[4, 2]]}          {'val': -2, 'from': [[4, 3]]}          {'val': 2, 'from': [[4, 4]]}          {'val': 6, 'from': [[4, 5]]}           {'val': 6, 'from': [[4, 5]]}             {'val': 8, 'from': [[5, 6], [4, 6]]}  {'val': 6, 'from': [[5, 7]]}          {'val': 8, 'from': [[4, 9], [5, 8], [4, 8]]}  {'val': 6, 'from': [[5, 9]]}
# A - 6   {'val': -12, 'from': [5, 0]}   {'val': -8, 'from': [[5, 1]]}    {'val': -6, 'from': [[5, 2]]}          {'val': -4, 'from': [[5, 3]]}          {'val': 4, 'from': [[5, 4]]}          {'val': 4, 'from': [[5, 5]]}           {'val': 4, 'from': [[5, 6], [5, 5]]}     {'val': 6, 'from': [[5, 7]]}          {'val': 10, 'from': [[5, 7]]}         {'val': 8, 'from': [[6, 8]]}                  {'val': 6, 'from': [[6, 9], [5, 9]]}
# C - 7   {'val': -14, 'from': [6, 0]}   {'val': -10, 'from': [[6, 1]]}   {'val': -8, 'from': [[6, 2]]}          {'val': -6, 'from': [[6, 3]]}          {'val': 2, 'from': [[6, 4]]}          {'val': 2, 'from': [[6, 5], [6, 4]]}   {'val': 2, 'from': [[6, 6], [6, 5]]}     {'val': 8, 'from': [[6, 7]]}          {'val': 8, 'from': [[6, 8]]}          {'val': 12, 'from': [[6, 8]]}                 {'val': 10, 'from': [[7, 9]]}
# G - 8   {'val': -16, 'from': [7, 0]}   {'val': -8, 'from': [[7, 1]]}    {'val': -6, 'from': [[7, 2], [8, 1]]}  {'val': -4, 'from': [[7, 3], [8, 2]]}  {'val': 0, 'from': [[7, 4]]}          {'val': 0, 'from': [[7, 5], [7, 4]]}   {'val': 4, 'from': [[7, 6], [7, 5]]}     {'val': 6, 'from': [[7, 7]]}          {'val': 6, 'from': [[7, 8], [7, 7]]}  {'val': 10, 'from': [[7, 9]]}                 {'val': 14, 'from': [[7, 9]]}
# C - 9   {'val': -18, 'from': [8, 0]}   {'val': -10, 'from': [[8, 1]]}   {'val': -8, 'from': [[8, 2]]}          {'val': -6, 'from': [[8, 3]]}          {'val': -2, 'from': [[8, 4]]}         {'val': -2, 'from': [[8, 5], [8, 4]]}  {'val': 2, 'from': [[8, 6]]}             {'val': 8, 'from': [[8, 7]]}          {'val': 6, 'from': [[9, 7]]}          {'val': 12, 'from': [[8, 9]]}                 {'val': 12, 'from': [[8, 10]]}
# A - 10  {'val': -20, 'from': [9, 0]}   {'val': -12, 'from': [[9, 1]]}   {'val': -10, 'from': [[9, 2]]}         {'val': -8, 'from': [[9, 3]]}          {'val': 0, 'from': [[9, 4]]}          {'val': -2, 'from': [[10, 4]]}         {'val': 0, 'from': [[9, 6]]}             {'val': 6, 'from': [[9, 7]]}          {'val': 10, 'from': [[9, 7]]}         {'val': 10, 'from': [[9, 9]]}                 {'val': 10, 'from': [[9, 10], [9, 9]]}
# A - 11  {'val': -22, 'from': [10, 0]}  {'val': -14, 'from': [[10, 1]]}  {'val': -12, 'from': [[10, 2]]}        {'val': -10, 'from': [[10, 3]]}        {'val': 2, 'from': [[10, 4]]}         {'val': 0, 'from': [[11, 4]]}          {'val': -2, 'from': [[10, 6], [11, 5]]}  {'val': 4, 'from': [[10, 7]]}         {'val': 12, 'from': [[10, 8]]}        {'val': 10, 'from': [[11, 8]]}                {'val': 8, 'from': [[10, 10], [11, 9], [10, 9]]}
# T - 12  {'val': -24, 'from': [11, 0]}  {'val': -16, 'from': [[11, 1]]}  {'val': -14, 'from': [[11, 2]]}        {'val': -12, 'from': [[11, 3]]}        {'val': 0, 'from': [[11, 4]]}         {'val': 4, 'from': [[11, 4]]}          {'val': 2, 'from': [[12, 5]]}            {'val': 2, 'from': [[11, 7]]}         {'val': 10, 'from': [[11, 8]]}        {'val': 10, 'from': [[11, 8]]}                {'val': 8, 'from': [[12, 9], [11, 9]]}
#
# 4 - 5
# -1      - - 0                          G - 1                           G - 2                                    G - 3                                    A - 4                                  T - 5                                             G - 6                                 C - 7                                 A - 8                                  C - 9                                  G - 10
# - - 0   {'val': 0, 'from': None}       {'val': -2, 'from': [0, 0]}     {'val': -4, 'from': [0, 1]}              {'val': -6, 'from': [0, 2]}              {'val': -8, 'from': [0, 3]}            {'val': -10, 'from': [0, 4]}                      {'val': -12, 'from': [0, 5]}          {'val': -14, 'from': [0, 6]}          {'val': -16, 'from': [0, 7]}           {'val': -18, 'from': [0, 8]}           {'val': -20, 'from': [0, 9]}
# G - 1   {'val': -2, 'from': [0, 0]}    {'val': 2, 'from': [[0, 0]]}    {'val': 4, 'from': [[1, 1]]}             {'val': 6, 'from': [[1, 2]]}             {'val': 4, 'from': [[1, 3]]}           {'val': 2, 'from': [[1, 4]]}                      {'val': 4, 'from': [[1, 5]]}          {'val': 2, 'from': [[1, 6]]}          {'val': 0, 'from': [[1, 7]]}           {'val': -2, 'from': [[1, 8]]}          {'val': 0, 'from': [[1, 9]]}
# T - 2   {'val': -4, 'from': [1, 0]}    {'val': 0, 'from': [[1, 1]]}    {'val': 2, 'from': [[1, 2]]}             {'val': 4, 'from': [[1, 3]]}             {'val': 4, 'from': [[1, 3]]}           {'val': 6, 'from': [[2, 4], [1, 4]]}              {'val': 4, 'from': [[2, 5]]}          {'val': 2, 'from': [[2, 6], [1, 6]]}  {'val': 0, 'from': [[2, 7], [1, 7]]}   {'val': -2, 'from': [[2, 8], [1, 8]]}  {'val': -2, 'from': [[1, 10]]}
# G - 3   {'val': -6, 'from': [2, 0]}    {'val': 2, 'from': [[2, 1]]}    {'val': 4, 'from': [[2, 2], [3, 1]]}     {'val': 6, 'from': [[2, 3], [3, 2]]}     {'val': 4, 'from': [[3, 3]]}           {'val': 4, 'from': [[2, 5]]}                      {'val': 8, 'from': [[2, 5]]}          {'val': 6, 'from': [[3, 6]]}          {'val': 4, 'from': [[3, 7]]}           {'val': 2, 'from': [[3, 8]]}           {'val': 4, 'from': [[3, 9]]}
# C - 4   {'val': -8, 'from': [3, 0]}    {'val': 0, 'from': [[3, 1]]}    {'val': 2, 'from': [[3, 2]]}             {'val': 4, 'from': [[3, 3]]}             {'val': 4, 'from': [[3, 3]]}           {'val': 2, 'from': [[3, 5], [4, 4], [3, 4]]}      {'val': 6, 'from': [[3, 6]]}          {'val': 10, 'from': [[3, 6]]}         {'val': 8, 'from': [[4, 7]]}           {'val': 10, 'from': [[4, 8]]}          {'val': 8, 'from': [[4, 9]]}
# T - 5   {'val': -10, 'from': [4, 0]}   {'val': -2, 'from': [[4, 1]]}   {'val': 0, 'from': [[4, 2]]}             {'val': 2, 'from': [[4, 3]]}             {'val': 2, 'from': [[4, 4], [4, 3]]}   {'val': 6, 'from': [[4, 4]]}                      {'val': 4, 'from': [[4, 6], [5, 5]]}  {'val': 8, 'from': [[4, 7]]}          {'val': 8, 'from': [[4, 7]]}           {'val': 8, 'from': [[4, 9]]}           {'val': 8, 'from': [[4, 9]]}
# A - 6   {'val': -12, 'from': [5, 0]}   {'val': -4, 'from': [[5, 1]]}   {'val': -2, 'from': [[5, 2]]}            {'val': 0, 'from': [[5, 3]]}             {'val': 4, 'from': [[5, 4], [5, 3]]}   {'val': 4, 'from': [[5, 5]]}                      {'val': 4, 'from': [[5, 5]]}          {'val': 6, 'from': [[5, 7]]}          {'val': 10, 'from': [[5, 8], [5, 7]]}  {'val': 8, 'from': [[6, 8]]}           {'val': 6, 'from': [[5, 10], [6, 9], [5, 9]]}
# C - 7   {'val': -14, 'from': [6, 0]}   {'val': -6, 'from': [[6, 1]]}   {'val': -4, 'from': [[6, 2]]}            {'val': -2, 'from': [[6, 3]]}            {'val': 2, 'from': [[6, 4]]}           {'val': 2, 'from': [[6, 5], [6, 4]]}              {'val': 2, 'from': [[6, 6], [6, 5]]}  {'val': 8, 'from': [[6, 7]]}          {'val': 8, 'from': [[6, 8]]}           {'val': 12, 'from': [[6, 8]]}          {'val': 10, 'from': [[7, 9]]}
# G - 8   {'val': -16, 'from': [7, 0]}   {'val': -4, 'from': [[7, 1]]}   {'val': -2, 'from': [[7, 2], [8, 1]]}    {'val': 0, 'from': [[7, 3], [8, 2]]}     {'val': 0, 'from': [[7, 4]]}           {'val': 0, 'from': [[7, 5], [7, 4]]}              {'val': 4, 'from': [[7, 6], [7, 5]]}  {'val': 6, 'from': [[7, 7]]}          {'val': 6, 'from': [[7, 8], [7, 7]]}   {'val': 10, 'from': [[7, 9]]}          {'val': 14, 'from': [[7, 9]]}
# C - 9   {'val': -18, 'from': [8, 0]}   {'val': -6, 'from': [[8, 1]]}   {'val': -4, 'from': [[8, 2]]}            {'val': -2, 'from': [[8, 3]]}            {'val': -2, 'from': [[8, 4], [8, 3]]}  {'val': -2, 'from': [[8, 5], [8, 4]]}             {'val': 2, 'from': [[8, 6]]}          {'val': 8, 'from': [[8, 7]]}          {'val': 6, 'from': [[9, 7]]}           {'val': 12, 'from': [[8, 9]]}          {'val': 12, 'from': [[8, 10]]}
# C - 10  {'val': -20, 'from': [9, 0]}   {'val': -8, 'from': [[9, 1]]}   {'val': -6, 'from': [[9, 2]]}            {'val': -4, 'from': [[9, 3]]}            {'val': -4, 'from': [[9, 4], [9, 3]]}  {'val': -4, 'from': [[9, 5], [9, 4]]}             {'val': 0, 'from': [[9, 6]]}          {'val': 10, 'from': [[9, 7]]}         {'val': 8, 'from': [[10, 7]]}          {'val': 14, 'from': [[9, 9]]}          {'val': 12, 'from': [[10, 9]]}
# G - 11  {'val': -22, 'from': [10, 0]}  {'val': -6, 'from': [[10, 1]]}  {'val': -4, 'from': [[10, 2], [11, 1]]}  {'val': -2, 'from': [[10, 3], [11, 2]]}  {'val': -4, 'from': [[11, 3]]}         {'val': -6, 'from': [[10, 5], [11, 4], [10, 4]]}  {'val': 2, 'from': [[10, 6]]}         {'val': 8, 'from': [[10, 7]]}         {'val': 8, 'from': [[10, 7]]}          {'val': 12, 'from': [[10, 9]]}         {'val': 16, 'from': [[10, 9]]}

# %%
txt = """S1: G--T-AATGGACGT
S2: GCGT---TG-C-GT

S1: G--T-AATGG-A-CGT
S3: GCATCA-CG-CAAT–-

S1: G---TAATGGAC-GT
S4: GTGCTA-CG-C-CG-

S1: G--TAATGG-ACGT
S5: GGGA--TG-CACG-

S2: GCGTTGC-----GT
S3: GCAT-C-ACGCAAT

S2: GCGTTGC------GT
S4: G--T-GCTACGCCG-

S2: GCG--TTGC--GT
S5: GG-GAT-GCACG-

S3: G--CATCACGC-AAT
S4: GTGCT-A-CGCCG--

S3: G--CAT-CACGCAA-T
S5: GGGA-TGC----A-CG

S4: G---TGCTACGCCG
S5: GGGATGCA-C---G"""

txt = txt.split("\n\n")
txt = [x.split("\n") for x in txt]
txt
# Out:
# [['S1: G--T-AATGGACGT', 'S2: GCGT---TG-C-GT'],
#  ['S1: G--T-AATGG-A-CGT', 'S3: GCATCA-CG-CAAT–-'],
#  ['S1: G---TAATGGAC-GT', 'S4: GTGCTA-CG-C-CG-'],
#  ['S1: G--TAATGG-ACGT', 'S5: GGGA--TG-CACG-'],
#  ['S2: GCGTTGC-----GT', 'S3: GCAT-C-ACGCAAT'],
#  ['S2: GCGTTGC------GT', 'S4: G--T-GCTACGCCG-'],
#  ['S2: GCG--TTGC--GT', 'S5: GG-GAT-GCACG-'],
#  ['S3: G--CATCACGC-AAT', 'S4: GTGCT-A-CGCCG--'],
#  ['S3: G--CAT-CACGCAA-T', 'S5: GGGA-TGC----A-CG'],
#  ['S4: G---TGCTACGCCG', 'S5: GGGATGCA-C---G']]

# %%
for row in txt:
    s1 = row[0].split(" ")[1]
    s2 = row[1].split(" ")[1]

    n_gap = 0
    mat = 0
    for i in range(len(s1)):
        if s1[i] != "-" and s2[i] != "-":
            n_gap += 1
            if s1[i] == s2[i]:
                mat += 1
    per = 1 - (mat / n_gap)
    print(row[0])
    print(row[1])
    print("Not Gap:", n_gap)
    print("Match:", mat)
    print("Percent:", round(per, 5))
    print()
# Out:
# S1: G--T-AATGGACGT
# S2: GCGT---TG-C-GT
# Not Gap: 7
# Match: 6
# Percent: 0.14286
#
# S1: G--T-AATGG-A-CGT
# S3: GCATCA-CG-CAAT–-
# Not Gap: 8
# Match: 5
# Percent: 0.375
#
# S1: G---TAATGGAC-GT
# S4: GTGCTA-CG-C-CG-
# Not Gap: 7
# Match: 5
# Percent: 0.28571
#
# S1: G--TAATGG-ACGT
# S5: GGGA--TG-CACG-
# Not Gap: 7
# Match: 6
# Percent: 0.14286
#
# S2: GCGTTGC-----GT
# S3: GCAT-C-ACGCAAT
# Not Gap: 7
# Match: 4
# Percent: 0.42857
#
# S2: GCGTTGC------GT
# S4: G--T-GCTACGCCG-
# Not Gap: 5
# Match: 5
# Percent: 0.0
#
# S2: GCG--TTGC--GT
# S5: GG-GAT-GCACG-
# Not Gap: 6
# Match: 5
# Percent: 0.16667
#
# S3: G--CATCACGC-AAT
# S4: GTGCT-A-CGCCG--
# Not Gap: 8
# Match: 5
# Percent: 0.375
#
# S3: G--CAT-CACGCAA-T
# S5: GGGA-TGC----A-CG
# Not Gap: 6
# Match: 4
# Percent: 0.33333
#
# S4: G---TGCTACGCCG
# S5: GGGATGCA-C---G
# Not Gap: 7
# Match: 6
# Percent: 0.14286

# %%
table = get_pairwise_table(data_p1, display=True)
# Out:
# +--------+---+----+---+----+----+
# | corner | 1 |  2 | 3 |  4 |  5 |
# +--------+---+----+---+----+----+
# | 1      |   | 12 | 4 | 10 | 16 |
# +--------+---+----+---+----+----+
# | 2      |   |    | 4 | 10 | 12 |
# +--------+---+----+---+----+----+
# | 3      |   |    |   |  6 |  8 |
# +--------+---+----+---+----+----+
# | 4      |   |    |   |    | 16 |
# +--------+---+----+---+----+----+
# | 5      |   |    |   |    |    |
# +--------+---+----+---+----+----+

# %% [markdown]
# # Problem 2

# %%
for i, k1 in enumerate(data_p2):
    for j, k2 in enumerate(data_p2):
        if i < j and k1 != k2:
            print(k1, "-", k2)
            _, _ = needleman_wunsch(data_p2[k1], data_p2[k2], display=1, s_match=2, s_nomatch=-1)
            print()
# Out:
# 1 - 2
# -1     - - 0                        C - 1                                 T - 2                                  A - 3                                  G - 4                                  C - 5                                 C - 6                                 T - 7                          C - 8                                  A - 9
# - - 0  {'val': 0, 'from': None}     {'val': -1, 'from': [0, 0]}           {'val': -2, 'from': [0, 1]}            {'val': -3, 'from': [0, 2]}            {'val': -4, 'from': [0, 3]}            {'val': -5, 'from': [0, 4]}           {'val': -6, 'from': [0, 5]}           {'val': -7, 'from': [0, 6]}    {'val': -8, 'from': [0, 7]}            {'val': -9, 'from': [0, 8]}
# G - 1  {'val': -1, 'from': [0, 0]}  {'val': -1, 'from': [[0, 0]]}         {'val': -2, 'from': [[1, 1], [0, 1]]}  {'val': -3, 'from': [[1, 2], [0, 2]]}  {'val': -1, 'from': [[1, 3], [0, 3]]}  {'val': -2, 'from': [[1, 4]]}         {'val': -3, 'from': [[1, 5]]}         {'val': -4, 'from': [[1, 6]]}  {'val': -5, 'from': [[1, 7]]}          {'val': -6, 'from': [[1, 8]]}
# C - 2  {'val': -2, 'from': [1, 0]}  {'val': 1, 'from': [[1, 1], [1, 0]]}  {'val': 0, 'from': [[2, 1]]}           {'val': -1, 'from': [[2, 2]]}          {'val': -2, 'from': [[1, 4], [2, 3]]}  {'val': 1, 'from': [[1, 4]]}          {'val': 3, 'from': [[2, 5]]}          {'val': 2, 'from': [[2, 6]]}   {'val': 4, 'from': [[2, 7]]}           {'val': 3, 'from': [[2, 8]]}
# C - 3  {'val': -3, 'from': [2, 0]}  {'val': 3, 'from': [[2, 1]]}          {'val': 2, 'from': [[3, 1]]}           {'val': 1, 'from': [[3, 2]]}           {'val': 0, 'from': [[3, 3]]}           {'val': 3, 'from': [[2, 5]]}          {'val': 5, 'from': [[2, 6], [3, 5]]}  {'val': 4, 'from': [[3, 6]]}   {'val': 6, 'from': [[2, 8], [3, 7]]}   {'val': 5, 'from': [[3, 8]]}
# C - 4  {'val': -4, 'from': [3, 0]}  {'val': 5, 'from': [[3, 1]]}          {'val': 4, 'from': [[4, 1]]}           {'val': 3, 'from': [[4, 2]]}           {'val': 2, 'from': [[4, 3]]}           {'val': 5, 'from': [[3, 5]]}          {'val': 7, 'from': [[3, 6], [4, 5]]}  {'val': 6, 'from': [[4, 6]]}   {'val': 8, 'from': [[3, 8], [4, 7]]}   {'val': 7, 'from': [[4, 8]]}
# C - 5  {'val': -5, 'from': [4, 0]}  {'val': 7, 'from': [[4, 1]]}          {'val': 6, 'from': [[5, 1]]}           {'val': 5, 'from': [[5, 2]]}           {'val': 4, 'from': [[5, 3]]}           {'val': 7, 'from': [[4, 5]]}          {'val': 9, 'from': [[4, 6], [5, 5]]}  {'val': 8, 'from': [[5, 6]]}   {'val': 10, 'from': [[4, 8], [5, 7]]}  {'val': 9, 'from': [[5, 8]]}
# T - 6  {'val': -6, 'from': [5, 0]}  {'val': 6, 'from': [[5, 1]]}          {'val': 9, 'from': [[5, 1]]}           {'val': 8, 'from': [[6, 2]]}           {'val': 7, 'from': [[6, 3]]}           {'val': 6, 'from': [[5, 5], [6, 4]]}  {'val': 8, 'from': [[5, 6]]}          {'val': 11, 'from': [[5, 6]]}  {'val': 10, 'from': [[6, 7]]}          {'val': 9, 'from': [[6, 8], [5, 8]]}
# A - 7  {'val': -7, 'from': [6, 0]}  {'val': 5, 'from': [[6, 1]]}          {'val': 8, 'from': [[6, 2]]}           {'val': 11, 'from': [[6, 2]]}          {'val': 10, 'from': [[7, 3]]}          {'val': 9, 'from': [[7, 4]]}          {'val': 8, 'from': [[7, 5]]}          {'val': 10, 'from': [[6, 7]]}  {'val': 10, 'from': [[6, 7]]}          {'val': 12, 'from': [[7, 8], [6, 8]]}
#
# 1 - 3
# -1     - - 0                        C - 1                                 T - 2                                  A - 3                                  C - 4                                  G - 5                                  C - 6                                 T - 7                          A - 8                          A - 9
# - - 0  {'val': 0, 'from': None}     {'val': -1, 'from': [0, 0]}           {'val': -2, 'from': [0, 1]}            {'val': -3, 'from': [0, 2]}            {'val': -4, 'from': [0, 3]}            {'val': -5, 'from': [0, 4]}            {'val': -6, 'from': [0, 5]}           {'val': -7, 'from': [0, 6]}    {'val': -8, 'from': [0, 7]}    {'val': -9, 'from': [0, 8]}
# G - 1  {'val': -1, 'from': [0, 0]}  {'val': -1, 'from': [[0, 0]]}         {'val': -2, 'from': [[1, 1], [0, 1]]}  {'val': -3, 'from': [[1, 2], [0, 2]]}  {'val': -4, 'from': [[1, 3], [0, 3]]}  {'val': -2, 'from': [[1, 4], [0, 4]]}  {'val': -3, 'from': [[1, 5]]}         {'val': -4, 'from': [[1, 6]]}  {'val': -5, 'from': [[1, 7]]}  {'val': -6, 'from': [[1, 8]]}
# C - 2  {'val': -2, 'from': [1, 0]}  {'val': 1, 'from': [[1, 1], [1, 0]]}  {'val': 0, 'from': [[2, 1]]}           {'val': -1, 'from': [[2, 2]]}          {'val': 1, 'from': [[2, 3]]}           {'val': 0, 'from': [[2, 4]]}           {'val': 2, 'from': [[2, 5]]}          {'val': 1, 'from': [[2, 6]]}   {'val': 0, 'from': [[2, 7]]}   {'val': -1, 'from': [[2, 8]]}
# C - 3  {'val': -3, 'from': [2, 0]}  {'val': 3, 'from': [[2, 1]]}          {'val': 2, 'from': [[3, 1]]}           {'val': 1, 'from': [[3, 2]]}           {'val': 3, 'from': [[2, 4], [3, 3]]}   {'val': 2, 'from': [[3, 4]]}           {'val': 4, 'from': [[2, 6], [3, 5]]}  {'val': 3, 'from': [[3, 6]]}   {'val': 2, 'from': [[3, 7]]}   {'val': 1, 'from': [[3, 8]]}
# C - 4  {'val': -4, 'from': [3, 0]}  {'val': 5, 'from': [[3, 1]]}          {'val': 4, 'from': [[4, 1]]}           {'val': 3, 'from': [[4, 2]]}           {'val': 5, 'from': [[3, 4], [4, 3]]}   {'val': 4, 'from': [[4, 4]]}           {'val': 6, 'from': [[3, 6], [4, 5]]}  {'val': 5, 'from': [[4, 6]]}   {'val': 4, 'from': [[4, 7]]}   {'val': 3, 'from': [[4, 8]]}
# C - 5  {'val': -5, 'from': [4, 0]}  {'val': 7, 'from': [[4, 1]]}          {'val': 6, 'from': [[5, 1]]}           {'val': 5, 'from': [[5, 2]]}           {'val': 7, 'from': [[4, 4], [5, 3]]}   {'val': 6, 'from': [[5, 4]]}           {'val': 8, 'from': [[4, 6], [5, 5]]}  {'val': 7, 'from': [[5, 6]]}   {'val': 6, 'from': [[5, 7]]}   {'val': 5, 'from': [[5, 8]]}
# T - 6  {'val': -6, 'from': [5, 0]}  {'val': 6, 'from': [[5, 1]]}          {'val': 9, 'from': [[5, 1]]}           {'val': 8, 'from': [[6, 2]]}           {'val': 7, 'from': [[6, 3]]}           {'val': 6, 'from': [[6, 4], [5, 4]]}   {'val': 7, 'from': [[5, 6]]}          {'val': 10, 'from': [[5, 6]]}  {'val': 9, 'from': [[6, 7]]}   {'val': 8, 'from': [[6, 8]]}
# A - 7  {'val': -7, 'from': [6, 0]}  {'val': 5, 'from': [[6, 1]]}          {'val': 8, 'from': [[6, 2]]}           {'val': 11, 'from': [[6, 2]]}          {'val': 10, 'from': [[7, 3]]}          {'val': 9, 'from': [[7, 4]]}           {'val': 8, 'from': [[7, 5]]}          {'val': 9, 'from': [[6, 7]]}   {'val': 12, 'from': [[6, 7]]}  {'val': 14, 'from': [[7, 8]]}
#
# 1 - 4
# -1     - - 0                        C - 1                                 G - 2                                 A - 3                                 G - 4                                 C - 5                          T - 6                          T - 7                          A - 8
# - - 0  {'val': 0, 'from': None}     {'val': -1, 'from': [0, 0]}           {'val': -2, 'from': [0, 1]}           {'val': -3, 'from': [0, 2]}           {'val': -4, 'from': [0, 3]}           {'val': -5, 'from': [0, 4]}    {'val': -6, 'from': [0, 5]}    {'val': -7, 'from': [0, 6]}    {'val': -8, 'from': [0, 7]}
# G - 1  {'val': -1, 'from': [0, 0]}  {'val': -1, 'from': [[0, 0]]}         {'val': 1, 'from': [[1, 1], [0, 1]]}  {'val': 0, 'from': [[1, 2]]}          {'val': 2, 'from': [[1, 3]]}          {'val': 1, 'from': [[1, 4]]}   {'val': 0, 'from': [[1, 5]]}   {'val': -1, 'from': [[1, 6]]}  {'val': -2, 'from': [[1, 7]]}
# C - 2  {'val': -2, 'from': [1, 0]}  {'val': 1, 'from': [[1, 1], [1, 0]]}  {'val': 0, 'from': [[1, 2], [2, 1]]}  {'val': 0, 'from': [[1, 2]]}          {'val': 1, 'from': [[1, 4]]}          {'val': 4, 'from': [[1, 4]]}   {'val': 3, 'from': [[2, 5]]}   {'val': 2, 'from': [[2, 6]]}   {'val': 1, 'from': [[2, 7]]}
# C - 3  {'val': -3, 'from': [2, 0]}  {'val': 3, 'from': [[2, 1]]}          {'val': 2, 'from': [[3, 1]]}          {'val': 1, 'from': [[3, 2]]}          {'val': 0, 'from': [[2, 4], [3, 3]]}  {'val': 6, 'from': [[2, 5]]}   {'val': 5, 'from': [[3, 5]]}   {'val': 4, 'from': [[3, 6]]}   {'val': 3, 'from': [[3, 7]]}
# C - 4  {'val': -4, 'from': [3, 0]}  {'val': 5, 'from': [[3, 1]]}          {'val': 4, 'from': [[4, 1]]}          {'val': 3, 'from': [[4, 2]]}          {'val': 2, 'from': [[4, 3]]}          {'val': 8, 'from': [[3, 5]]}   {'val': 7, 'from': [[4, 5]]}   {'val': 6, 'from': [[4, 6]]}   {'val': 5, 'from': [[4, 7]]}
# C - 5  {'val': -5, 'from': [4, 0]}  {'val': 7, 'from': [[4, 1]]}          {'val': 6, 'from': [[5, 1]]}          {'val': 5, 'from': [[5, 2]]}          {'val': 4, 'from': [[5, 3]]}          {'val': 10, 'from': [[4, 5]]}  {'val': 9, 'from': [[5, 5]]}   {'val': 8, 'from': [[5, 6]]}   {'val': 7, 'from': [[5, 7]]}
# T - 6  {'val': -6, 'from': [5, 0]}  {'val': 6, 'from': [[5, 1]]}          {'val': 6, 'from': [[5, 1]]}          {'val': 5, 'from': [[6, 2], [5, 2]]}  {'val': 4, 'from': [[6, 3], [5, 3]]}  {'val': 9, 'from': [[5, 5]]}   {'val': 12, 'from': [[5, 5]]}  {'val': 14, 'from': [[6, 6]]}  {'val': 13, 'from': [[6, 7]]}
# A - 7  {'val': -7, 'from': [6, 0]}  {'val': 5, 'from': [[6, 1]]}          {'val': 5, 'from': [[6, 2], [6, 1]]}  {'val': 8, 'from': [[6, 2]]}          {'val': 7, 'from': [[7, 3]]}          {'val': 8, 'from': [[6, 5]]}   {'val': 11, 'from': [[6, 6]]}  {'val': 13, 'from': [[6, 7]]}  {'val': 16, 'from': [[6, 7]]}
#
# 1 - 5
# -1     - - 0                        C - 1                                 G - 2                                 C - 3                         G - 4                                 A - 5                                 C - 6                                 T - 7
# - - 0  {'val': 0, 'from': None}     {'val': -1, 'from': [0, 0]}           {'val': -2, 'from': [0, 1]}           {'val': -3, 'from': [0, 2]}   {'val': -4, 'from': [0, 3]}           {'val': -5, 'from': [0, 4]}           {'val': -6, 'from': [0, 5]}           {'val': -7, 'from': [0, 6]}
# G - 1  {'val': -1, 'from': [0, 0]}  {'val': -1, 'from': [[0, 0]]}         {'val': 1, 'from': [[1, 1], [0, 1]]}  {'val': 0, 'from': [[1, 2]]}  {'val': 2, 'from': [[1, 3]]}          {'val': 1, 'from': [[1, 4]]}          {'val': 0, 'from': [[1, 5]]}          {'val': -1, 'from': [[1, 6]]}
# C - 2  {'val': -2, 'from': [1, 0]}  {'val': 1, 'from': [[1, 1], [1, 0]]}  {'val': 0, 'from': [[1, 2], [2, 1]]}  {'val': 3, 'from': [[1, 2]]}  {'val': 2, 'from': [[2, 3]]}          {'val': 1, 'from': [[2, 4], [1, 4]]}  {'val': 3, 'from': [[2, 5], [1, 5]]}  {'val': 2, 'from': [[2, 6]]}
# C - 3  {'val': -3, 'from': [2, 0]}  {'val': 3, 'from': [[2, 1]]}          {'val': 2, 'from': [[3, 1]]}          {'val': 5, 'from': [[2, 3]]}  {'val': 4, 'from': [[3, 3]]}          {'val': 3, 'from': [[3, 4]]}          {'val': 5, 'from': [[2, 6], [3, 5]]}  {'val': 4, 'from': [[3, 6]]}
# C - 4  {'val': -4, 'from': [3, 0]}  {'val': 5, 'from': [[3, 1]]}          {'val': 4, 'from': [[4, 1]]}          {'val': 7, 'from': [[3, 3]]}  {'val': 6, 'from': [[4, 3]]}          {'val': 5, 'from': [[4, 4]]}          {'val': 7, 'from': [[3, 6], [4, 5]]}  {'val': 6, 'from': [[4, 6]]}
# C - 5  {'val': -5, 'from': [4, 0]}  {'val': 7, 'from': [[4, 1]]}          {'val': 6, 'from': [[5, 1]]}          {'val': 9, 'from': [[4, 3]]}  {'val': 8, 'from': [[5, 3]]}          {'val': 7, 'from': [[5, 4]]}          {'val': 9, 'from': [[4, 6], [5, 5]]}  {'val': 8, 'from': [[5, 6]]}
# T - 6  {'val': -6, 'from': [5, 0]}  {'val': 6, 'from': [[5, 1]]}          {'val': 6, 'from': [[5, 1]]}          {'val': 8, 'from': [[5, 3]]}  {'val': 8, 'from': [[5, 3]]}          {'val': 7, 'from': [[6, 4], [5, 4]]}  {'val': 8, 'from': [[5, 6]]}          {'val': 11, 'from': [[5, 6]]}
# A - 7  {'val': -7, 'from': [6, 0]}  {'val': 5, 'from': [[6, 1]]}          {'val': 5, 'from': [[6, 2], [6, 1]]}  {'val': 7, 'from': [[6, 3]]}  {'val': 7, 'from': [[6, 4], [6, 3]]}  {'val': 10, 'from': [[6, 4]]}         {'val': 9, 'from': [[7, 5]]}          {'val': 10, 'from': [[6, 7]]}
#
# 2 - 3
# -1     - - 0                        C - 1                          T - 2                                 A - 3                                 C - 4                                 G - 5                                 C - 6                          T - 7                                  A - 8                                  A - 9
# - - 0  {'val': 0, 'from': None}     {'val': -1, 'from': [0, 0]}    {'val': -2, 'from': [0, 1]}           {'val': -3, 'from': [0, 2]}           {'val': -4, 'from': [0, 3]}           {'val': -5, 'from': [0, 4]}           {'val': -6, 'from': [0, 5]}    {'val': -7, 'from': [0, 6]}            {'val': -8, 'from': [0, 7]}            {'val': -9, 'from': [0, 8]}
# C - 1  {'val': -1, 'from': [0, 0]}  {'val': 2, 'from': [[0, 0]]}   {'val': 1, 'from': [[1, 1]]}          {'val': 0, 'from': [[1, 2]]}          {'val': 2, 'from': [[1, 3]]}          {'val': 1, 'from': [[1, 4]]}          {'val': 3, 'from': [[1, 5]]}   {'val': 2, 'from': [[1, 6]]}           {'val': 1, 'from': [[1, 7]]}           {'val': 0, 'from': [[1, 8]]}
# T - 2  {'val': -2, 'from': [1, 0]}  {'val': 1, 'from': [[1, 1]]}   {'val': 4, 'from': [[1, 1]]}          {'val': 3, 'from': [[2, 2]]}          {'val': 2, 'from': [[2, 3]]}          {'val': 1, 'from': [[2, 4], [1, 4]]}  {'val': 2, 'from': [[1, 6]]}   {'val': 5, 'from': [[1, 6]]}           {'val': 4, 'from': [[2, 7]]}           {'val': 3, 'from': [[2, 8]]}
# A - 3  {'val': -3, 'from': [2, 0]}  {'val': 0, 'from': [[2, 1]]}   {'val': 3, 'from': [[2, 2]]}          {'val': 6, 'from': [[2, 2]]}          {'val': 5, 'from': [[3, 3]]}          {'val': 4, 'from': [[3, 4]]}          {'val': 3, 'from': [[3, 5]]}   {'val': 4, 'from': [[2, 7]]}           {'val': 7, 'from': [[2, 7]]}           {'val': 9, 'from': [[3, 8]]}
# G - 4  {'val': -4, 'from': [3, 0]}  {'val': -1, 'from': [[3, 1]]}  {'val': 2, 'from': [[3, 2]]}          {'val': 5, 'from': [[3, 3]]}          {'val': 5, 'from': [[3, 3]]}          {'val': 7, 'from': [[4, 4], [3, 4]]}  {'val': 6, 'from': [[4, 5]]}   {'val': 5, 'from': [[4, 6]]}           {'val': 6, 'from': [[3, 8]]}           {'val': 8, 'from': [[3, 9]]}
# C - 5  {'val': -5, 'from': [4, 0]}  {'val': 1, 'from': [[4, 1]]}   {'val': 1, 'from': [[4, 2]]}          {'val': 4, 'from': [[4, 3]]}          {'val': 7, 'from': [[4, 4], [4, 3]]}  {'val': 6, 'from': [[4, 5], [5, 4]]}  {'val': 9, 'from': [[4, 5]]}   {'val': 8, 'from': [[5, 6]]}           {'val': 7, 'from': [[5, 7]]}           {'val': 7, 'from': [[4, 9]]}
# C - 6  {'val': -6, 'from': [5, 0]}  {'val': 3, 'from': [[5, 1]]}   {'val': 2, 'from': [[6, 1]]}          {'val': 3, 'from': [[5, 3]]}          {'val': 9, 'from': [[5, 4]]}          {'val': 8, 'from': [[6, 4]]}          {'val': 11, 'from': [[5, 6]]}  {'val': 10, 'from': [[6, 6]]}          {'val': 9, 'from': [[6, 7]]}           {'val': 8, 'from': [[6, 8]]}
# T - 7  {'val': -7, 'from': [6, 0]}  {'val': 2, 'from': [[6, 1]]}   {'val': 5, 'from': [[6, 1]]}          {'val': 4, 'from': [[7, 2]]}          {'val': 8, 'from': [[6, 4]]}          {'val': 8, 'from': [[6, 4]]}          {'val': 10, 'from': [[6, 6]]}  {'val': 13, 'from': [[6, 6]]}          {'val': 12, 'from': [[7, 7]]}          {'val': 11, 'from': [[7, 8]]}
# C - 8  {'val': -8, 'from': [7, 0]}  {'val': 4, 'from': [[7, 1]]}   {'val': 4, 'from': [[7, 2]]}          {'val': 4, 'from': [[7, 2]]}          {'val': 10, 'from': [[7, 4]]}         {'val': 9, 'from': [[8, 4]]}          {'val': 12, 'from': [[7, 6]]}  {'val': 12, 'from': [[7, 7]]}          {'val': 12, 'from': [[7, 7]]}          {'val': 11, 'from': [[8, 8], [7, 8]]}
# A - 9  {'val': -9, 'from': [8, 0]}  {'val': 3, 'from': [[8, 1]]}   {'val': 3, 'from': [[8, 2], [8, 1]]}  {'val': 6, 'from': [[8, 3], [8, 2]]}  {'val': 9, 'from': [[8, 4]]}          {'val': 9, 'from': [[8, 4]]}          {'val': 11, 'from': [[8, 6]]}  {'val': 11, 'from': [[8, 7], [8, 6]]}  {'val': 14, 'from': [[8, 8], [8, 7]]}  {'val': 16, 'from': [[9, 8]]}
#
# 2 - 4
# -1     - - 0                        C - 1                          G - 2                                 A - 3                                 G - 4                                  C - 5                          T - 6                                 T - 7                          A - 8
# - - 0  {'val': 0, 'from': None}     {'val': -1, 'from': [0, 0]}    {'val': -2, 'from': [0, 1]}           {'val': -3, 'from': [0, 2]}           {'val': -4, 'from': [0, 3]}            {'val': -5, 'from': [0, 4]}    {'val': -6, 'from': [0, 5]}           {'val': -7, 'from': [0, 6]}    {'val': -8, 'from': [0, 7]}
# C - 1  {'val': -1, 'from': [0, 0]}  {'val': 2, 'from': [[0, 0]]}   {'val': 1, 'from': [[1, 1]]}          {'val': 0, 'from': [[1, 2]]}          {'val': -1, 'from': [[1, 3]]}          {'val': 1, 'from': [[1, 4]]}   {'val': 0, 'from': [[1, 5]]}          {'val': -1, 'from': [[1, 6]]}  {'val': -2, 'from': [[1, 7]]}
# T - 2  {'val': -2, 'from': [1, 0]}  {'val': 1, 'from': [[1, 1]]}   {'val': 1, 'from': [[1, 1]]}          {'val': 0, 'from': [[2, 2], [1, 2]]}  {'val': -1, 'from': [[2, 3], [1, 3]]}  {'val': 0, 'from': [[1, 5]]}   {'val': 3, 'from': [[1, 5]]}          {'val': 5, 'from': [[2, 6]]}   {'val': 4, 'from': [[2, 7]]}
# A - 3  {'val': -3, 'from': [2, 0]}  {'val': 0, 'from': [[2, 1]]}   {'val': 0, 'from': [[2, 2], [2, 1]]}  {'val': 3, 'from': [[2, 2]]}          {'val': 2, 'from': [[3, 3]]}           {'val': 1, 'from': [[3, 4]]}   {'val': 2, 'from': [[2, 6]]}          {'val': 4, 'from': [[2, 7]]}   {'val': 7, 'from': [[2, 7]]}
# G - 4  {'val': -4, 'from': [3, 0]}  {'val': -1, 'from': [[3, 1]]}  {'val': 2, 'from': [[3, 2], [3, 1]]}  {'val': 2, 'from': [[3, 3]]}          {'val': 5, 'from': [[3, 3]]}           {'val': 4, 'from': [[4, 4]]}   {'val': 3, 'from': [[4, 5]]}          {'val': 3, 'from': [[3, 7]]}   {'val': 6, 'from': [[3, 8]]}
# C - 5  {'val': -5, 'from': [4, 0]}  {'val': 1, 'from': [[4, 1]]}   {'val': 1, 'from': [[4, 2]]}          {'val': 1, 'from': [[4, 3], [4, 2]]}  {'val': 4, 'from': [[4, 4]]}           {'val': 7, 'from': [[4, 4]]}   {'val': 6, 'from': [[5, 5]]}          {'val': 5, 'from': [[5, 6]]}   {'val': 5, 'from': [[4, 8]]}
# C - 6  {'val': -6, 'from': [5, 0]}  {'val': 3, 'from': [[5, 1]]}   {'val': 2, 'from': [[6, 1]]}          {'val': 1, 'from': [[6, 2]]}          {'val': 3, 'from': [[5, 4]]}           {'val': 9, 'from': [[5, 5]]}   {'val': 8, 'from': [[6, 5]]}          {'val': 7, 'from': [[6, 6]]}   {'val': 6, 'from': [[6, 7]]}
# T - 7  {'val': -7, 'from': [6, 0]}  {'val': 2, 'from': [[6, 1]]}   {'val': 2, 'from': [[6, 1]]}          {'val': 1, 'from': [[7, 2], [6, 2]]}  {'val': 2, 'from': [[6, 4]]}           {'val': 8, 'from': [[6, 5]]}   {'val': 11, 'from': [[6, 5]]}         {'val': 13, 'from': [[7, 6]]}  {'val': 12, 'from': [[7, 7]]}
# C - 8  {'val': -8, 'from': [7, 0]}  {'val': 4, 'from': [[7, 1]]}   {'val': 3, 'from': [[8, 1]]}          {'val': 2, 'from': [[8, 2]]}          {'val': 1, 'from': [[7, 4], [8, 3]]}   {'val': 10, 'from': [[7, 5]]}  {'val': 10, 'from': [[7, 6]]}         {'val': 12, 'from': [[7, 7]]}  {'val': 12, 'from': [[7, 7]]}
# A - 9  {'val': -9, 'from': [8, 0]}  {'val': 3, 'from': [[8, 1]]}   {'val': 3, 'from': [[8, 1]]}          {'val': 5, 'from': [[9, 2], [8, 2]]}  {'val': 4, 'from': [[9, 3]]}           {'val': 9, 'from': [[8, 5]]}   {'val': 9, 'from': [[8, 6], [8, 5]]}  {'val': 11, 'from': [[8, 7]]}  {'val': 14, 'from': [[8, 8], [8, 7]]}
#
# 2 - 5
# -1     - - 0                        C - 1                          G - 2                                 C - 3                         G - 4                                         A - 5                                         C - 6                                 T - 7
# - - 0  {'val': 0, 'from': None}     {'val': -1, 'from': [0, 0]}    {'val': -2, 'from': [0, 1]}           {'val': -3, 'from': [0, 2]}   {'val': -4, 'from': [0, 3]}                   {'val': -5, 'from': [0, 4]}                   {'val': -6, 'from': [0, 5]}           {'val': -7, 'from': [0, 6]}
# C - 1  {'val': -1, 'from': [0, 0]}  {'val': 2, 'from': [[0, 0]]}   {'val': 1, 'from': [[1, 1]]}          {'val': 3, 'from': [[1, 2]]}  {'val': 2, 'from': [[1, 3]]}                  {'val': 1, 'from': [[1, 4]]}                  {'val': 3, 'from': [[1, 5]]}          {'val': 2, 'from': [[1, 6]]}
# T - 2  {'val': -2, 'from': [1, 0]}  {'val': 1, 'from': [[1, 1]]}   {'val': 1, 'from': [[1, 1]]}          {'val': 2, 'from': [[1, 3]]}  {'val': 2, 'from': [[1, 3]]}                  {'val': 1, 'from': [[2, 4], [1, 4]]}          {'val': 2, 'from': [[1, 6]]}          {'val': 5, 'from': [[1, 6]]}
# A - 3  {'val': -3, 'from': [2, 0]}  {'val': 0, 'from': [[2, 1]]}   {'val': 0, 'from': [[2, 2], [2, 1]]}  {'val': 1, 'from': [[2, 3]]}  {'val': 1, 'from': [[2, 4], [2, 3]]}          {'val': 4, 'from': [[2, 4]]}                  {'val': 3, 'from': [[3, 5]]}          {'val': 4, 'from': [[2, 7]]}
# G - 4  {'val': -4, 'from': [3, 0]}  {'val': -1, 'from': [[3, 1]]}  {'val': 2, 'from': [[3, 2], [3, 1]]}  {'val': 1, 'from': [[4, 2]]}  {'val': 3, 'from': [[3, 4], [4, 3], [3, 3]]}  {'val': 3, 'from': [[3, 5]]}                  {'val': 3, 'from': [[3, 5]]}          {'val': 3, 'from': [[3, 7]]}
# C - 5  {'val': -5, 'from': [4, 0]}  {'val': 1, 'from': [[4, 1]]}   {'val': 1, 'from': [[4, 2]]}          {'val': 4, 'from': [[4, 2]]}  {'val': 3, 'from': [[5, 3]]}                  {'val': 2, 'from': [[4, 5], [5, 4], [4, 4]]}  {'val': 5, 'from': [[4, 6], [4, 5]]}  {'val': 4, 'from': [[5, 6]]}
# C - 6  {'val': -6, 'from': [5, 0]}  {'val': 3, 'from': [[5, 1]]}   {'val': 2, 'from': [[6, 1]]}          {'val': 6, 'from': [[5, 3]]}  {'val': 5, 'from': [[6, 3]]}                  {'val': 4, 'from': [[6, 4]]}                  {'val': 7, 'from': [[5, 6]]}          {'val': 6, 'from': [[6, 6]]}
# T - 7  {'val': -7, 'from': [6, 0]}  {'val': 2, 'from': [[6, 1]]}   {'val': 2, 'from': [[6, 1]]}          {'val': 5, 'from': [[6, 3]]}  {'val': 5, 'from': [[6, 3]]}                  {'val': 4, 'from': [[7, 4], [6, 4]]}          {'val': 6, 'from': [[6, 6]]}          {'val': 9, 'from': [[6, 6]]}
# C - 8  {'val': -8, 'from': [7, 0]}  {'val': 4, 'from': [[7, 1]]}   {'val': 3, 'from': [[8, 1]]}          {'val': 7, 'from': [[7, 3]]}  {'val': 6, 'from': [[8, 3]]}                  {'val': 5, 'from': [[8, 4]]}                  {'val': 8, 'from': [[7, 6]]}          {'val': 8, 'from': [[7, 7]]}
# A - 9  {'val': -9, 'from': [8, 0]}  {'val': 3, 'from': [[8, 1]]}   {'val': 3, 'from': [[8, 1]]}          {'val': 6, 'from': [[8, 3]]}  {'val': 6, 'from': [[8, 3]]}                  {'val': 8, 'from': [[9, 4], [8, 4]]}          {'val': 7, 'from': [[8, 6], [9, 5]]}  {'val': 7, 'from': [[8, 7], [8, 6]]}
#
# 3 - 4
# -1     - - 0                        C - 1                         G - 2                                 A - 3                                 G - 4                                  C - 5                                 T - 6                                 T - 7                                         A - 8
# - - 0  {'val': 0, 'from': None}     {'val': -1, 'from': [0, 0]}   {'val': -2, 'from': [0, 1]}           {'val': -3, 'from': [0, 2]}           {'val': -4, 'from': [0, 3]}            {'val': -5, 'from': [0, 4]}           {'val': -6, 'from': [0, 5]}           {'val': -7, 'from': [0, 6]}                   {'val': -8, 'from': [0, 7]}
# C - 1  {'val': -1, 'from': [0, 0]}  {'val': 2, 'from': [[0, 0]]}  {'val': 1, 'from': [[1, 1]]}          {'val': 0, 'from': [[1, 2]]}          {'val': -1, 'from': [[1, 3]]}          {'val': 1, 'from': [[1, 4]]}          {'val': 0, 'from': [[1, 5]]}          {'val': -1, 'from': [[1, 6]]}                 {'val': -2, 'from': [[1, 7]]}
# T - 2  {'val': -2, 'from': [1, 0]}  {'val': 1, 'from': [[1, 1]]}  {'val': 1, 'from': [[1, 1]]}          {'val': 0, 'from': [[2, 2], [1, 2]]}  {'val': -1, 'from': [[2, 3], [1, 3]]}  {'val': 0, 'from': [[1, 5]]}          {'val': 3, 'from': [[1, 5]]}          {'val': 5, 'from': [[2, 6]]}                  {'val': 4, 'from': [[2, 7]]}
# A - 3  {'val': -3, 'from': [2, 0]}  {'val': 0, 'from': [[2, 1]]}  {'val': 0, 'from': [[2, 2], [2, 1]]}  {'val': 3, 'from': [[2, 2]]}          {'val': 2, 'from': [[3, 3]]}           {'val': 1, 'from': [[3, 4]]}          {'val': 2, 'from': [[2, 6]]}          {'val': 4, 'from': [[2, 7]]}                  {'val': 7, 'from': [[2, 7]]}
# C - 4  {'val': -4, 'from': [3, 0]}  {'val': 2, 'from': [[3, 1]]}  {'val': 1, 'from': [[4, 1]]}          {'val': 2, 'from': [[3, 3]]}          {'val': 2, 'from': [[3, 3]]}           {'val': 4, 'from': [[4, 4], [3, 4]]}  {'val': 3, 'from': [[4, 5]]}          {'val': 3, 'from': [[3, 7]]}                  {'val': 6, 'from': [[3, 8]]}
# G - 5  {'val': -5, 'from': [4, 0]}  {'val': 1, 'from': [[4, 1]]}  {'val': 4, 'from': [[4, 1]]}          {'val': 3, 'from': [[5, 2]]}          {'val': 5, 'from': [[5, 3]]}           {'val': 4, 'from': [[5, 4]]}          {'val': 3, 'from': [[5, 5], [4, 5]]}  {'val': 2, 'from': [[4, 7], [5, 6], [4, 6]]}  {'val': 5, 'from': [[4, 8]]}
# C - 6  {'val': -6, 'from': [5, 0]}  {'val': 3, 'from': [[5, 1]]}  {'val': 3, 'from': [[5, 2]]}          {'val': 3, 'from': [[5, 2]]}          {'val': 4, 'from': [[5, 4]]}           {'val': 7, 'from': [[5, 4]]}          {'val': 6, 'from': [[6, 5]]}          {'val': 5, 'from': [[6, 6]]}                  {'val': 4, 'from': [[5, 8], [6, 7]]}
# T - 7  {'val': -7, 'from': [6, 0]}  {'val': 2, 'from': [[6, 1]]}  {'val': 2, 'from': [[6, 2], [6, 1]]}  {'val': 2, 'from': [[6, 3], [6, 2]]}  {'val': 3, 'from': [[6, 4]]}           {'val': 6, 'from': [[6, 5]]}          {'val': 9, 'from': [[6, 5]]}          {'val': 11, 'from': [[7, 6]]}                 {'val': 10, 'from': [[7, 7]]}
# A - 8  {'val': -8, 'from': [7, 0]}  {'val': 1, 'from': [[7, 1]]}  {'val': 1, 'from': [[7, 2], [7, 1]]}  {'val': 4, 'from': [[7, 3], [7, 2]]}  {'val': 3, 'from': [[8, 3]]}           {'val': 5, 'from': [[7, 5]]}          {'val': 8, 'from': [[7, 6]]}          {'val': 10, 'from': [[7, 7]]}                 {'val': 13, 'from': [[7, 7]]}
# A - 9  {'val': -9, 'from': [8, 0]}  {'val': 0, 'from': [[8, 1]]}  {'val': 0, 'from': [[8, 2], [8, 1]]}  {'val': 6, 'from': [[8, 3]]}          {'val': 5, 'from': [[9, 3]]}           {'val': 4, 'from': [[8, 5], [9, 4]]}  {'val': 7, 'from': [[8, 6]]}          {'val': 9, 'from': [[8, 7]]}                  {'val': 15, 'from': [[8, 8]]}
#
# 3 - 5
# -1     - - 0                        C - 1                         G - 2                                 C - 3                                 G - 4                                 A - 5                                 C - 6                         T - 7
# - - 0  {'val': 0, 'from': None}     {'val': -1, 'from': [0, 0]}   {'val': -2, 'from': [0, 1]}           {'val': -3, 'from': [0, 2]}           {'val': -4, 'from': [0, 3]}           {'val': -5, 'from': [0, 4]}           {'val': -6, 'from': [0, 5]}   {'val': -7, 'from': [0, 6]}
# C - 1  {'val': -1, 'from': [0, 0]}  {'val': 2, 'from': [[0, 0]]}  {'val': 1, 'from': [[1, 1]]}          {'val': 3, 'from': [[1, 2]]}          {'val': 2, 'from': [[1, 3]]}          {'val': 1, 'from': [[1, 4]]}          {'val': 3, 'from': [[1, 5]]}  {'val': 2, 'from': [[1, 6]]}
# T - 2  {'val': -2, 'from': [1, 0]}  {'val': 1, 'from': [[1, 1]]}  {'val': 1, 'from': [[1, 1]]}          {'val': 2, 'from': [[1, 3]]}          {'val': 2, 'from': [[1, 3]]}          {'val': 1, 'from': [[2, 4], [1, 4]]}  {'val': 2, 'from': [[1, 6]]}  {'val': 5, 'from': [[1, 6]]}
# A - 3  {'val': -3, 'from': [2, 0]}  {'val': 0, 'from': [[2, 1]]}  {'val': 0, 'from': [[2, 2], [2, 1]]}  {'val': 1, 'from': [[2, 3]]}          {'val': 1, 'from': [[2, 4], [2, 3]]}  {'val': 4, 'from': [[2, 4]]}          {'val': 3, 'from': [[3, 5]]}  {'val': 4, 'from': [[2, 7]]}
# C - 4  {'val': -4, 'from': [3, 0]}  {'val': 2, 'from': [[3, 1]]}  {'val': 1, 'from': [[4, 1]]}          {'val': 3, 'from': [[3, 3], [4, 2]]}  {'val': 2, 'from': [[4, 3]]}          {'val': 3, 'from': [[3, 5]]}          {'val': 6, 'from': [[3, 5]]}  {'val': 5, 'from': [[4, 6]]}
# G - 5  {'val': -5, 'from': [4, 0]}  {'val': 1, 'from': [[4, 1]]}  {'val': 4, 'from': [[4, 1]]}          {'val': 3, 'from': [[5, 2]]}          {'val': 5, 'from': [[5, 3], [4, 3]]}  {'val': 4, 'from': [[5, 4]]}          {'val': 5, 'from': [[4, 6]]}  {'val': 5, 'from': [[4, 6]]}
# C - 6  {'val': -6, 'from': [5, 0]}  {'val': 3, 'from': [[5, 1]]}  {'val': 3, 'from': [[5, 2]]}          {'val': 6, 'from': [[5, 2]]}          {'val': 5, 'from': [[6, 3]]}          {'val': 4, 'from': [[6, 4], [5, 4]]}  {'val': 7, 'from': [[5, 6]]}  {'val': 6, 'from': [[6, 6]]}
# T - 7  {'val': -7, 'from': [6, 0]}  {'val': 2, 'from': [[6, 1]]}  {'val': 2, 'from': [[6, 2], [6, 1]]}  {'val': 5, 'from': [[6, 3]]}          {'val': 5, 'from': [[6, 3]]}          {'val': 4, 'from': [[7, 4], [6, 4]]}  {'val': 6, 'from': [[6, 6]]}  {'val': 9, 'from': [[6, 6]]}
# A - 8  {'val': -8, 'from': [7, 0]}  {'val': 1, 'from': [[7, 1]]}  {'val': 1, 'from': [[7, 2], [7, 1]]}  {'val': 4, 'from': [[7, 3]]}          {'val': 4, 'from': [[7, 4], [7, 3]]}  {'val': 7, 'from': [[7, 4]]}          {'val': 6, 'from': [[8, 5]]}  {'val': 8, 'from': [[7, 7]]}
# A - 9  {'val': -9, 'from': [8, 0]}  {'val': 0, 'from': [[8, 1]]}  {'val': 0, 'from': [[8, 2], [8, 1]]}  {'val': 3, 'from': [[8, 3]]}          {'val': 3, 'from': [[8, 4], [8, 3]]}  {'val': 9, 'from': [[8, 5]]}          {'val': 8, 'from': [[9, 5]]}  {'val': 7, 'from': [[8, 7], [9, 6]]}
#
# 4 - 5
# -1     - - 0                        C - 1                          G - 2                         C - 3                         G - 4                                 A - 5                                         C - 6                                 T - 7
# - - 0  {'val': 0, 'from': None}     {'val': -1, 'from': [0, 0]}    {'val': -2, 'from': [0, 1]}   {'val': -3, 'from': [0, 2]}   {'val': -4, 'from': [0, 3]}           {'val': -5, 'from': [0, 4]}                   {'val': -6, 'from': [0, 5]}           {'val': -7, 'from': [0, 6]}
# C - 1  {'val': -1, 'from': [0, 0]}  {'val': 2, 'from': [[0, 0]]}   {'val': 1, 'from': [[1, 1]]}  {'val': 3, 'from': [[1, 2]]}  {'val': 2, 'from': [[1, 3]]}          {'val': 1, 'from': [[1, 4]]}                  {'val': 3, 'from': [[1, 5]]}          {'val': 2, 'from': [[1, 6]]}
# G - 2  {'val': -2, 'from': [1, 0]}  {'val': 1, 'from': [[1, 1]]}   {'val': 4, 'from': [[1, 1]]}  {'val': 3, 'from': [[2, 2]]}  {'val': 5, 'from': [[2, 3], [1, 3]]}  {'val': 4, 'from': [[2, 4]]}                  {'val': 3, 'from': [[2, 5]]}          {'val': 2, 'from': [[2, 6], [1, 6]]}
# A - 3  {'val': -3, 'from': [2, 0]}  {'val': 0, 'from': [[2, 1]]}   {'val': 3, 'from': [[2, 2]]}  {'val': 3, 'from': [[2, 2]]}  {'val': 4, 'from': [[2, 4]]}          {'val': 7, 'from': [[2, 4]]}                  {'val': 6, 'from': [[3, 5]]}          {'val': 5, 'from': [[3, 6]]}
# G - 4  {'val': -4, 'from': [3, 0]}  {'val': -1, 'from': [[3, 1]]}  {'val': 5, 'from': [[3, 2]]}  {'val': 4, 'from': [[4, 2]]}  {'val': 6, 'from': [[3, 4], [4, 3]]}  {'val': 6, 'from': [[3, 5]]}                  {'val': 6, 'from': [[3, 5]]}          {'val': 5, 'from': [[4, 6], [3, 6]]}
# C - 5  {'val': -5, 'from': [4, 0]}  {'val': 1, 'from': [[4, 1]]}   {'val': 4, 'from': [[4, 2]]}  {'val': 7, 'from': [[4, 2]]}  {'val': 6, 'from': [[5, 3]]}          {'val': 5, 'from': [[4, 5], [5, 4], [4, 4]]}  {'val': 8, 'from': [[4, 6], [4, 5]]}  {'val': 7, 'from': [[5, 6]]}
# T - 6  {'val': -6, 'from': [5, 0]}  {'val': 0, 'from': [[5, 1]]}   {'val': 3, 'from': [[5, 2]]}  {'val': 6, 'from': [[5, 3]]}  {'val': 6, 'from': [[5, 3]]}          {'val': 5, 'from': [[6, 4], [5, 4]]}          {'val': 7, 'from': [[5, 6]]}          {'val': 10, 'from': [[5, 6]]}
# T - 7  {'val': -7, 'from': [6, 0]}  {'val': -1, 'from': [[6, 1]]}  {'val': 2, 'from': [[6, 2]]}  {'val': 5, 'from': [[6, 3]]}  {'val': 5, 'from': [[6, 4], [6, 3]]}  {'val': 5, 'from': [[6, 4]]}                  {'val': 6, 'from': [[6, 6]]}          {'val': 12, 'from': [[6, 7]]}
# A - 8  {'val': -8, 'from': [7, 0]}  {'val': -2, 'from': [[7, 1]]}  {'val': 1, 'from': [[7, 2]]}  {'val': 4, 'from': [[7, 3]]}  {'val': 4, 'from': [[7, 4], [7, 3]]}  {'val': 7, 'from': [[7, 5], [7, 4]]}          {'val': 6, 'from': [[8, 5]]}          {'val': 11, 'from': [[7, 7]]}

# %%
table, kc = get_center_seq(data_p2, s_match=2, s_nomatch=-1, display=True)
kc
# Out:
# +--------+----+----+----+----+----+-------+
# | corner |  1 |  2 |  3 |  4 |  5 | Score |
# +--------+----+----+----+----+----+-------+
# | 1      |    | 12 | 14 | 16 | 10 | 52    |
# +--------+----+----+----+----+----+-------+
# | 2      | 12 |    | 16 | 14 |  7 | 49    |
# +--------+----+----+----+----+----+-------+
# | 3      | 14 | 16 |    | 15 |  7 | 52    |
# +--------+----+----+----+----+----+-------+
# | 4      | 16 | 14 | 15 |    | 11 | 56    |
# +--------+----+----+----+----+----+-------+
# | 5      | 10 |  7 |  7 | 11 |    | 35    |
# +--------+----+----+----+----+----+-------+
# 4

# %%
for i, k in enumerate(data_p2):
    if k != kc:
        print(kc, "-", k)
        _, _ = needleman_wunsch(data_p2[kc], data_p2[k], display=1)
        print()
# Out:
# 4 - 1
# -1     - - 0                         G - 1                                 C - 2                                  C - 3                                          C - 4                          C - 5                         T - 6                                 A - 7
# - - 0  {'val': 0, 'from': None}      {'val': -2, 'from': [0, 0]}           {'val': -4, 'from': [0, 1]}            {'val': -6, 'from': [0, 2]}                    {'val': -8, 'from': [0, 3]}    {'val': -10, 'from': [0, 4]}  {'val': -12, 'from': [0, 5]}          {'val': -14, 'from': [0, 6]}
# C - 1  {'val': -2, 'from': [0, 0]}   {'val': -2, 'from': [[0, 0]]}         {'val': 0, 'from': [[1, 1], [0, 1]]}   {'val': 2, 'from': [[1, 2]]}                   {'val': 4, 'from': [[1, 3]]}   {'val': 6, 'from': [[1, 4]]}  {'val': 4, 'from': [[1, 5]]}          {'val': 2, 'from': [[1, 6]]}
# G - 2  {'val': -4, 'from': [1, 0]}   {'val': 0, 'from': [[1, 1], [1, 0]]}  {'val': -2, 'from': [[1, 2], [2, 1]]}  {'val': 0, 'from': [[1, 3]]}                   {'val': 2, 'from': [[1, 4]]}   {'val': 4, 'from': [[1, 5]]}  {'val': 4, 'from': [[1, 5]]}          {'val': 2, 'from': [[2, 6], [1, 6]]}
# A - 3  {'val': -6, 'from': [2, 0]}   {'val': -2, 'from': [[2, 1]]}         {'val': -2, 'from': [[2, 1]]}          {'val': -2, 'from': [[2, 3]]}                  {'val': 0, 'from': [[2, 4]]}   {'val': 2, 'from': [[2, 5]]}  {'val': 2, 'from': [[2, 6], [2, 5]]}  {'val': 6, 'from': [[2, 6]]}
# G - 4  {'val': -8, 'from': [3, 0]}   {'val': 0, 'from': [[3, 1]]}          {'val': -2, 'from': [[4, 1]]}          {'val': -4, 'from': [[3, 3], [4, 2], [3, 2]]}  {'val': -2, 'from': [[3, 4]]}  {'val': 0, 'from': [[3, 5]]}  {'val': 0, 'from': [[3, 6], [3, 5]]}  {'val': 4, 'from': [[3, 7]]}
# C - 5  {'val': -10, 'from': [4, 0]}  {'val': -2, 'from': [[4, 1]]}         {'val': 2, 'from': [[4, 1]]}           {'val': 4, 'from': [[5, 2]]}                   {'val': 6, 'from': [[5, 3]]}   {'val': 8, 'from': [[5, 4]]}  {'val': 6, 'from': [[5, 5]]}          {'val': 4, 'from': [[5, 6]]}
# T - 6  {'val': -12, 'from': [5, 0]}  {'val': -4, 'from': [[5, 1]]}         {'val': 0, 'from': [[5, 2]]}           {'val': 2, 'from': [[5, 3]]}                   {'val': 4, 'from': [[5, 4]]}   {'val': 6, 'from': [[5, 5]]}  {'val': 10, 'from': [[5, 5]]}         {'val': 8, 'from': [[6, 6]]}
# T - 7  {'val': -14, 'from': [6, 0]}  {'val': -6, 'from': [[6, 1]]}         {'val': -2, 'from': [[6, 2]]}          {'val': 0, 'from': [[6, 3]]}                   {'val': 2, 'from': [[6, 4]]}   {'val': 4, 'from': [[6, 5]]}  {'val': 12, 'from': [[6, 6]]}         {'val': 10, 'from': [[7, 6]]}
# A - 8  {'val': -16, 'from': [7, 0]}  {'val': -8, 'from': [[7, 1]]}         {'val': -4, 'from': [[7, 2]]}          {'val': -2, 'from': [[7, 3]]}                  {'val': 0, 'from': [[7, 4]]}   {'val': 2, 'from': [[7, 5]]}  {'val': 10, 'from': [[7, 6]]}         {'val': 14, 'from': [[7, 6]]}
#
# 4 - 2
# -1     - - 0                         C - 1                          T - 2                                  A - 3                                  G - 4                                  C - 5                                  C - 6                                          T - 7                                  C - 8                                  A - 9
# - - 0  {'val': 0, 'from': None}      {'val': -2, 'from': [0, 0]}    {'val': -4, 'from': [0, 1]}            {'val': -6, 'from': [0, 2]}            {'val': -8, 'from': [0, 3]}            {'val': -10, 'from': [0, 4]}           {'val': -12, 'from': [0, 5]}                   {'val': -14, 'from': [0, 6]}           {'val': -16, 'from': [0, 7]}           {'val': -18, 'from': [0, 8]}
# C - 1  {'val': -2, 'from': [0, 0]}   {'val': 2, 'from': [[0, 0]]}   {'val': 0, 'from': [[1, 1]]}           {'val': -2, 'from': [[1, 2]]}          {'val': -4, 'from': [[1, 3]]}          {'val': -2, 'from': [[1, 4]]}          {'val': 0, 'from': [[1, 5]]}                   {'val': -2, 'from': [[1, 6]]}          {'val': 0, 'from': [[1, 7]]}           {'val': -2, 'from': [[1, 8]]}
# G - 2  {'val': -4, 'from': [1, 0]}   {'val': 0, 'from': [[1, 1]]}   {'val': 0, 'from': [[1, 1]]}           {'val': -2, 'from': [[2, 2], [1, 2]]}  {'val': 0, 'from': [[2, 3], [1, 3]]}   {'val': -2, 'from': [[2, 4]]}          {'val': -2, 'from': [[1, 6]]}                  {'val': -2, 'from': [[1, 6]]}          {'val': -2, 'from': [[1, 8]]}          {'val': -2, 'from': [[1, 8]]}
# A - 3  {'val': -6, 'from': [2, 0]}   {'val': -2, 'from': [[2, 1]]}  {'val': -2, 'from': [[2, 2], [2, 1]]}  {'val': 2, 'from': [[2, 2]]}           {'val': 0, 'from': [[3, 3]]}           {'val': -2, 'from': [[3, 4], [2, 4]]}  {'val': -4, 'from': [[2, 6], [3, 5], [2, 5]]}  {'val': -4, 'from': [[2, 7], [2, 6]]}  {'val': -4, 'from': [[2, 8], [2, 7]]}  {'val': 0, 'from': [[2, 9], [2, 8]]}
# G - 4  {'val': -8, 'from': [3, 0]}   {'val': -4, 'from': [[3, 1]]}  {'val': -4, 'from': [[3, 2], [3, 1]]}  {'val': 0, 'from': [[3, 3]]}           {'val': 4, 'from': [[3, 3]]}           {'val': 2, 'from': [[4, 4]]}           {'val': 0, 'from': [[4, 5]]}                   {'val': -2, 'from': [[4, 6]]}          {'val': -4, 'from': [[4, 7]]}          {'val': -2, 'from': [[3, 9]]}
# C - 5  {'val': -10, 'from': [4, 0]}  {'val': -2, 'from': [[4, 1]]}  {'val': -4, 'from': [[5, 1]]}          {'val': -2, 'from': [[4, 3]]}          {'val': 2, 'from': [[4, 4]]}           {'val': 6, 'from': [[4, 4]]}           {'val': 8, 'from': [[5, 5]]}                   {'val': 6, 'from': [[5, 6]]}           {'val': 8, 'from': [[5, 7]]}           {'val': 6, 'from': [[5, 8]]}
# T - 6  {'val': -12, 'from': [5, 0]}  {'val': -4, 'from': [[5, 1]]}  {'val': 0, 'from': [[5, 1]]}           {'val': -2, 'from': [[6, 2]]}          {'val': 0, 'from': [[5, 4]]}           {'val': 4, 'from': [[5, 5]]}           {'val': 6, 'from': [[5, 6]]}                   {'val': 10, 'from': [[5, 6]]}          {'val': 8, 'from': [[6, 7]]}           {'val': 6, 'from': [[6, 8], [5, 8]]}
# T - 7  {'val': -14, 'from': [6, 0]}  {'val': -6, 'from': [[6, 1]]}  {'val': 2, 'from': [[6, 2]]}           {'val': 0, 'from': [[7, 2]]}           {'val': -2, 'from': [[6, 4], [7, 3]]}  {'val': 2, 'from': [[6, 5]]}           {'val': 4, 'from': [[6, 6]]}                   {'val': 12, 'from': [[6, 7]]}          {'val': 10, 'from': [[7, 7]]}          {'val': 8, 'from': [[7, 8]]}
# A - 8  {'val': -16, 'from': [7, 0]}  {'val': -8, 'from': [[7, 1]]}  {'val': 0, 'from': [[7, 2]]}           {'val': 4, 'from': [[7, 2]]}           {'val': 2, 'from': [[8, 3]]}           {'val': 0, 'from': [[7, 5], [8, 4]]}   {'val': 2, 'from': [[7, 6]]}                   {'val': 10, 'from': [[7, 7]]}          {'val': 10, 'from': [[7, 7]]}          {'val': 12, 'from': [[8, 8], [7, 8]]}
#
# 4 - 3
# -1     - - 0                         C - 1                          T - 2                                  A - 3                                  C - 4                                  G - 5                                         C - 6                                  T - 7                                  A - 8                                  A - 9
# - - 0  {'val': 0, 'from': None}      {'val': -2, 'from': [0, 0]}    {'val': -4, 'from': [0, 1]}            {'val': -6, 'from': [0, 2]}            {'val': -8, 'from': [0, 3]}            {'val': -10, 'from': [0, 4]}                  {'val': -12, 'from': [0, 5]}           {'val': -14, 'from': [0, 6]}           {'val': -16, 'from': [0, 7]}           {'val': -18, 'from': [0, 8]}
# C - 1  {'val': -2, 'from': [0, 0]}   {'val': 2, 'from': [[0, 0]]}   {'val': 0, 'from': [[1, 1]]}           {'val': -2, 'from': [[1, 2]]}          {'val': 0, 'from': [[1, 3]]}           {'val': -2, 'from': [[1, 4]]}                 {'val': 0, 'from': [[1, 5]]}           {'val': -2, 'from': [[1, 6]]}          {'val': -4, 'from': [[1, 7]]}          {'val': -6, 'from': [[1, 8]]}
# G - 2  {'val': -4, 'from': [1, 0]}   {'val': 0, 'from': [[1, 1]]}   {'val': 0, 'from': [[1, 1]]}           {'val': -2, 'from': [[2, 2], [1, 2]]}  {'val': -2, 'from': [[1, 4]]}          {'val': 2, 'from': [[1, 4]]}                  {'val': 0, 'from': [[2, 5]]}           {'val': -2, 'from': [[2, 6], [1, 6]]}  {'val': -4, 'from': [[2, 7], [1, 7]]}  {'val': -6, 'from': [[2, 8], [1, 8]]}
# A - 3  {'val': -6, 'from': [2, 0]}   {'val': -2, 'from': [[2, 1]]}  {'val': -2, 'from': [[2, 2], [2, 1]]}  {'val': 2, 'from': [[2, 2]]}           {'val': 0, 'from': [[3, 3]]}           {'val': 0, 'from': [[2, 5]]}                  {'val': 0, 'from': [[2, 5]]}           {'val': -2, 'from': [[3, 6], [2, 6]]}  {'val': 0, 'from': [[3, 7], [2, 7]]}   {'val': 2, 'from': [[3, 8]]}
# G - 4  {'val': -8, 'from': [3, 0]}   {'val': -4, 'from': [[3, 1]]}  {'val': -4, 'from': [[3, 2], [3, 1]]}  {'val': 0, 'from': [[3, 3]]}           {'val': 0, 'from': [[3, 3]]}           {'val': 2, 'from': [[3, 5], [4, 4], [3, 4]]}  {'val': 0, 'from': [[4, 5]]}           {'val': -2, 'from': [[4, 6], [3, 6]]}  {'val': -2, 'from': [[3, 8]]}          {'val': 0, 'from': [[3, 9]]}
# C - 5  {'val': -10, 'from': [4, 0]}  {'val': -2, 'from': [[4, 1]]}  {'val': -4, 'from': [[5, 1]]}          {'val': -2, 'from': [[4, 3]]}          {'val': 2, 'from': [[4, 4], [4, 3]]}   {'val': 0, 'from': [[4, 5], [5, 4]]}          {'val': 4, 'from': [[4, 5]]}           {'val': 2, 'from': [[5, 6]]}           {'val': 0, 'from': [[5, 7]]}           {'val': -2, 'from': [[4, 9], [5, 8]]}
# T - 6  {'val': -12, 'from': [5, 0]}  {'val': -4, 'from': [[5, 1]]}  {'val': 0, 'from': [[5, 1]]}           {'val': -2, 'from': [[6, 2]]}          {'val': 0, 'from': [[5, 4]]}           {'val': 0, 'from': [[5, 4]]}                  {'val': 2, 'from': [[5, 6]]}           {'val': 6, 'from': [[5, 6]]}           {'val': 4, 'from': [[6, 7]]}           {'val': 2, 'from': [[6, 8]]}
# T - 7  {'val': -14, 'from': [6, 0]}  {'val': -6, 'from': [[6, 1]]}  {'val': 2, 'from': [[6, 2]]}           {'val': 0, 'from': [[7, 2]]}           {'val': -2, 'from': [[6, 4], [7, 3]]}  {'val': -2, 'from': [[6, 5], [6, 4]]}         {'val': 0, 'from': [[6, 6]]}           {'val': 8, 'from': [[6, 7]]}           {'val': 6, 'from': [[7, 7]]}           {'val': 4, 'from': [[7, 8]]}
# A - 8  {'val': -16, 'from': [7, 0]}  {'val': -8, 'from': [[7, 1]]}  {'val': 0, 'from': [[7, 2]]}           {'val': 4, 'from': [[7, 2]]}           {'val': 2, 'from': [[8, 3]]}           {'val': 0, 'from': [[8, 4]]}                  {'val': -2, 'from': [[7, 6], [8, 5]]}  {'val': 6, 'from': [[7, 7]]}           {'val': 10, 'from': [[7, 7]]}          {'val': 12, 'from': [[8, 8]]}
#
# 4 - 5
# -1     - - 0                         C - 1                          G - 2                          C - 3                         G - 4                                         A - 5                                         C - 6                                 T - 7
# - - 0  {'val': 0, 'from': None}      {'val': -2, 'from': [0, 0]}    {'val': -4, 'from': [0, 1]}    {'val': -6, 'from': [0, 2]}   {'val': -8, 'from': [0, 3]}                   {'val': -10, 'from': [0, 4]}                  {'val': -12, 'from': [0, 5]}          {'val': -14, 'from': [0, 6]}
# C - 1  {'val': -2, 'from': [0, 0]}   {'val': 2, 'from': [[0, 0]]}   {'val': 0, 'from': [[1, 1]]}   {'val': 2, 'from': [[1, 2]]}  {'val': 0, 'from': [[1, 3]]}                  {'val': -2, 'from': [[1, 4]]}                 {'val': 0, 'from': [[1, 5]]}          {'val': -2, 'from': [[1, 6]]}
# G - 2  {'val': -4, 'from': [1, 0]}   {'val': 0, 'from': [[1, 1]]}   {'val': 4, 'from': [[1, 1]]}   {'val': 2, 'from': [[2, 2]]}  {'val': 4, 'from': [[2, 3], [1, 3]]}          {'val': 2, 'from': [[2, 4]]}                  {'val': 0, 'from': [[2, 5]]}          {'val': -2, 'from': [[2, 6], [1, 6]]}
# A - 3  {'val': -6, 'from': [2, 0]}   {'val': -2, 'from': [[2, 1]]}  {'val': 2, 'from': [[2, 2]]}   {'val': 2, 'from': [[2, 2]]}  {'val': 2, 'from': [[2, 4]]}                  {'val': 6, 'from': [[2, 4]]}                  {'val': 4, 'from': [[3, 5]]}          {'val': 2, 'from': [[3, 6]]}
# G - 4  {'val': -8, 'from': [3, 0]}   {'val': -4, 'from': [[3, 1]]}  {'val': 4, 'from': [[3, 2]]}   {'val': 2, 'from': [[4, 2]]}  {'val': 4, 'from': [[3, 4], [4, 3], [3, 3]]}  {'val': 4, 'from': [[3, 5]]}                  {'val': 4, 'from': [[3, 5]]}          {'val': 2, 'from': [[4, 6], [3, 6]]}
# C - 5  {'val': -10, 'from': [4, 0]}  {'val': -2, 'from': [[4, 1]]}  {'val': 2, 'from': [[4, 2]]}   {'val': 6, 'from': [[4, 2]]}  {'val': 4, 'from': [[5, 3]]}                  {'val': 2, 'from': [[4, 5], [5, 4], [4, 4]]}  {'val': 6, 'from': [[4, 6], [4, 5]]}  {'val': 4, 'from': [[5, 6]]}
# T - 6  {'val': -12, 'from': [5, 0]}  {'val': -4, 'from': [[5, 1]]}  {'val': 0, 'from': [[5, 2]]}   {'val': 4, 'from': [[5, 3]]}  {'val': 4, 'from': [[5, 3]]}                  {'val': 2, 'from': [[6, 4], [5, 4]]}          {'val': 4, 'from': [[5, 6]]}          {'val': 8, 'from': [[5, 6]]}
# T - 7  {'val': -14, 'from': [6, 0]}  {'val': -6, 'from': [[6, 1]]}  {'val': -2, 'from': [[6, 2]]}  {'val': 2, 'from': [[6, 3]]}  {'val': 2, 'from': [[6, 4], [6, 3]]}          {'val': 2, 'from': [[6, 4]]}                  {'val': 2, 'from': [[6, 6]]}          {'val': 10, 'from': [[6, 7]]}
# A - 8  {'val': -16, 'from': [7, 0]}  {'val': -8, 'from': [[7, 1]]}  {'val': -4, 'from': [[7, 2]]}  {'val': 0, 'from': [[7, 3]]}  {'val': 0, 'from': [[7, 4], [7, 3]]}          {'val': 4, 'from': [[7, 5], [7, 4]]}          {'val': 2, 'from': [[8, 5]]}          {'val': 8, 'from': [[7, 7]]}

# %%
center = data_p2[4]

# %%
# Center (S4) with S1
table, kc = needleman_wunsch(center, data_p2[1], s_match=2, s_nomatch=-1, display=1)
# Out:
# -1     - - 0                        G - 1                                 C - 2                                 C - 3                                 C - 4                         C - 5                          T - 6                                 A - 7
# - - 0  {'val': 0, 'from': None}     {'val': -1, 'from': [0, 0]}           {'val': -2, 'from': [0, 1]}           {'val': -3, 'from': [0, 2]}           {'val': -4, 'from': [0, 3]}   {'val': -5, 'from': [0, 4]}    {'val': -6, 'from': [0, 5]}           {'val': -7, 'from': [0, 6]}
# C - 1  {'val': -1, 'from': [0, 0]}  {'val': -1, 'from': [[0, 0]]}         {'val': 1, 'from': [[1, 1], [0, 1]]}  {'val': 3, 'from': [[1, 2]]}          {'val': 5, 'from': [[1, 3]]}  {'val': 7, 'from': [[1, 4]]}   {'val': 6, 'from': [[1, 5]]}          {'val': 5, 'from': [[1, 6]]}
# G - 2  {'val': -2, 'from': [1, 0]}  {'val': 1, 'from': [[1, 1], [1, 0]]}  {'val': 0, 'from': [[1, 2], [2, 1]]}  {'val': 2, 'from': [[1, 3]]}          {'val': 4, 'from': [[1, 4]]}  {'val': 6, 'from': [[1, 5]]}   {'val': 6, 'from': [[1, 5]]}          {'val': 5, 'from': [[2, 6], [1, 6]]}
# A - 3  {'val': -3, 'from': [2, 0]}  {'val': 0, 'from': [[2, 1]]}          {'val': 0, 'from': [[2, 1]]}          {'val': 1, 'from': [[2, 3]]}          {'val': 3, 'from': [[2, 4]]}  {'val': 5, 'from': [[2, 5]]}   {'val': 5, 'from': [[2, 6], [2, 5]]}  {'val': 8, 'from': [[2, 6]]}
# G - 4  {'val': -4, 'from': [3, 0]}  {'val': 2, 'from': [[3, 1]]}          {'val': 1, 'from': [[4, 1]]}          {'val': 0, 'from': [[3, 3], [4, 2]]}  {'val': 2, 'from': [[3, 4]]}  {'val': 4, 'from': [[3, 5]]}   {'val': 4, 'from': [[3, 6], [3, 5]]}  {'val': 7, 'from': [[3, 7]]}
# C - 5  {'val': -5, 'from': [4, 0]}  {'val': 1, 'from': [[4, 1]]}          {'val': 4, 'from': [[4, 1]]}          {'val': 6, 'from': [[5, 2]]}          {'val': 8, 'from': [[5, 3]]}  {'val': 10, 'from': [[5, 4]]}  {'val': 9, 'from': [[5, 5]]}          {'val': 8, 'from': [[5, 6]]}
# T - 6  {'val': -6, 'from': [5, 0]}  {'val': 0, 'from': [[5, 1]]}          {'val': 3, 'from': [[5, 2]]}          {'val': 5, 'from': [[5, 3]]}          {'val': 7, 'from': [[5, 4]]}  {'val': 9, 'from': [[5, 5]]}   {'val': 12, 'from': [[5, 5]]}         {'val': 11, 'from': [[6, 6]]}
# T - 7  {'val': -7, 'from': [6, 0]}  {'val': -1, 'from': [[6, 1]]}         {'val': 2, 'from': [[6, 2]]}          {'val': 4, 'from': [[6, 3]]}          {'val': 6, 'from': [[6, 4]]}  {'val': 8, 'from': [[6, 5]]}   {'val': 14, 'from': [[6, 6]]}         {'val': 13, 'from': [[7, 6]]}
# A - 8  {'val': -8, 'from': [7, 0]}  {'val': -2, 'from': [[7, 1]]}         {'val': 1, 'from': [[7, 2]]}          {'val': 3, 'from': [[7, 3]]}          {'val': 5, 'from': [[7, 4]]}  {'val': 7, 'from': [[7, 5]]}   {'val': 13, 'from': [[7, 6]]}         {'val': 16, 'from': [[7, 6]]}

# %%
# Add gaps to center
center = "CGAGC---TTA"

# Center (S4) with S2
table, kc = needleman_wunsch(center, data_p2[2], s_match=2, s_nomatch=-1, display=1)
# Out:
# -1      - - 0                          C - 1                           T - 2                                  A - 3                                  G - 4                                 C - 5                                 C - 6                          T - 7                                 C - 8                                 A - 9
# - - 0   {'val': 0, 'from': None}       {'val': -1, 'from': [0, 0]}     {'val': -2, 'from': [0, 1]}            {'val': -3, 'from': [0, 2]}            {'val': -4, 'from': [0, 3]}           {'val': -5, 'from': [0, 4]}           {'val': -6, 'from': [0, 5]}    {'val': -7, 'from': [0, 6]}           {'val': -8, 'from': [0, 7]}           {'val': -9, 'from': [0, 8]}
# C - 1   {'val': -1, 'from': [0, 0]}    {'val': 2, 'from': [[0, 0]]}    {'val': 1, 'from': [[1, 1]]}           {'val': 0, 'from': [[1, 2]]}           {'val': -1, 'from': [[1, 3]]}         {'val': 1, 'from': [[1, 4]]}          {'val': 3, 'from': [[1, 5]]}   {'val': 2, 'from': [[1, 6]]}          {'val': 4, 'from': [[1, 7]]}          {'val': 3, 'from': [[1, 8]]}
# G - 2   {'val': -2, 'from': [1, 0]}    {'val': 1, 'from': [[1, 1]]}    {'val': 1, 'from': [[1, 1]]}           {'val': 0, 'from': [[2, 2], [1, 2]]}   {'val': 2, 'from': [[2, 3], [1, 3]]}  {'val': 1, 'from': [[2, 4]]}          {'val': 2, 'from': [[1, 6]]}   {'val': 2, 'from': [[1, 6]]}          {'val': 3, 'from': [[1, 8]]}          {'val': 3, 'from': [[1, 8]]}
# A - 3   {'val': -3, 'from': [2, 0]}    {'val': 0, 'from': [[2, 1]]}    {'val': 0, 'from': [[2, 2], [2, 1]]}   {'val': 3, 'from': [[2, 2]]}           {'val': 2, 'from': [[3, 3]]}          {'val': 1, 'from': [[3, 4], [2, 4]]}  {'val': 1, 'from': [[2, 6]]}   {'val': 1, 'from': [[2, 7], [2, 6]]}  {'val': 2, 'from': [[2, 8]]}          {'val': 5, 'from': [[2, 9], [2, 8]]}
# G - 4   {'val': -4, 'from': [3, 0]}    {'val': -1, 'from': [[3, 1]]}   {'val': -1, 'from': [[3, 2], [3, 1]]}  {'val': 2, 'from': [[3, 3]]}           {'val': 5, 'from': [[3, 3]]}          {'val': 4, 'from': [[4, 4]]}          {'val': 3, 'from': [[4, 5]]}   {'val': 2, 'from': [[4, 6]]}          {'val': 1, 'from': [[3, 8], [4, 7]]}  {'val': 4, 'from': [[3, 9]]}
# C - 5   {'val': -5, 'from': [4, 0]}    {'val': 1, 'from': [[4, 1]]}    {'val': 0, 'from': [[5, 1]]}           {'val': 1, 'from': [[4, 3]]}           {'val': 4, 'from': [[4, 4]]}          {'val': 7, 'from': [[4, 4]]}          {'val': 9, 'from': [[5, 5]]}   {'val': 8, 'from': [[5, 6]]}          {'val': 10, 'from': [[5, 7]]}         {'val': 9, 'from': [[5, 8]]}
# - - 6   {'val': -6, 'from': [5, 0]}    {'val': 0, 'from': [[5, 1]]}    {'val': 0, 'from': [[5, 1]]}           {'val': 0, 'from': [[5, 3]]}           {'val': 3, 'from': [[5, 4]]}          {'val': 6, 'from': [[5, 5]]}          {'val': 8, 'from': [[5, 6]]}   {'val': 8, 'from': [[5, 6]]}          {'val': 9, 'from': [[5, 8]]}          {'val': 9, 'from': [[5, 8]]}
# - - 7   {'val': -7, 'from': [6, 0]}    {'val': -1, 'from': [[6, 1]]}   {'val': -1, 'from': [[6, 2], [6, 1]]}  {'val': -1, 'from': [[6, 3], [6, 2]]}  {'val': 2, 'from': [[6, 4]]}          {'val': 5, 'from': [[6, 5]]}          {'val': 7, 'from': [[6, 6]]}   {'val': 7, 'from': [[6, 7], [6, 6]]}  {'val': 8, 'from': [[6, 8]]}          {'val': 8, 'from': [[6, 9], [6, 8]]}
# - - 8   {'val': -8, 'from': [7, 0]}    {'val': -2, 'from': [[7, 1]]}   {'val': -2, 'from': [[7, 2], [7, 1]]}  {'val': -2, 'from': [[7, 3], [7, 2]]}  {'val': 1, 'from': [[7, 4]]}          {'val': 4, 'from': [[7, 5]]}          {'val': 6, 'from': [[7, 6]]}   {'val': 6, 'from': [[7, 7], [7, 6]]}  {'val': 7, 'from': [[7, 8]]}          {'val': 7, 'from': [[7, 9], [7, 8]]}
# T - 9   {'val': -9, 'from': [8, 0]}    {'val': -3, 'from': [[8, 1]]}   {'val': 0, 'from': [[8, 2], [8, 1]]}   {'val': -1, 'from': [[9, 2]]}          {'val': 0, 'from': [[8, 4]]}          {'val': 3, 'from': [[8, 5]]}          {'val': 5, 'from': [[8, 6]]}   {'val': 8, 'from': [[8, 7], [8, 6]]}  {'val': 7, 'from': [[9, 7]]}          {'val': 6, 'from': [[8, 9], [9, 8], [8, 8]]}
# T - 10  {'val': -10, 'from': [9, 0]}   {'val': -4, 'from': [[9, 1]]}   {'val': 2, 'from': [[9, 2]]}           {'val': 1, 'from': [[10, 2]]}          {'val': 0, 'from': [[10, 3]]}         {'val': 2, 'from': [[9, 5]]}          {'val': 4, 'from': [[9, 6]]}   {'val': 10, 'from': [[9, 7]]}         {'val': 9, 'from': [[10, 7]]}         {'val': 8, 'from': [[10, 8]]}
# A - 11  {'val': -11, 'from': [10, 0]}  {'val': -5, 'from': [[10, 1]]}  {'val': 1, 'from': [[10, 2]]}          {'val': 4, 'from': [[10, 2]]}          {'val': 3, 'from': [[11, 3]]}         {'val': 2, 'from': [[11, 4]]}         {'val': 3, 'from': [[10, 6]]}  {'val': 9, 'from': [[10, 7]]}         {'val': 9, 'from': [[10, 7]]}         {'val': 11, 'from': [[11, 8], [10, 8]]}

# %% [markdown]
# # Bottom
